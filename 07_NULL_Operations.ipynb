# %%
import pandas as pd
import numpy as np
jee = pd.read_csv('JEE_Dropout_After_Class_12.csv',delimiter=',')

# %%
jee.isna().sum()
# Out:
# jee_main_score             0
# jee_advanced_score         0
# mock_test_score_avg        0
# school_board               0
# class_12_percent           0
# attempt_count              0
# coaching_institute      1209
# daily_study_hours          0
# family_income              0
# parent_education           0
# location_type              0
# peer_pressure_level        0
# mental_health_issues       0
# admission_taken            0
# dropout                    0
# dtype: int64

# %% [markdown]
# ### .interpolate will add in values in places of NaN according to the pattern in previous data

# %% [markdown]
# ### .fillna() will add in the value put inside the ()

# %% [markdown]
# ### .mean() does the mean of the data and adds instead of NaN when used with fillna().mean()

# %% [markdown]
# ### jee.dropna(subset=['coaching_institute'], inplace=True) will delete the rows that have NaN in the column "Coaching_Institute"

# %%
jee_nan = jee.copy()
jee_nan.dropna(subset=['coaching_institute'],inplace=True)
jee_nan.isna().sum()
# Out:
# jee_main_score          0
# jee_advanced_score      0
# mock_test_score_avg     0
# school_board            0
# class_12_percent        0
# attempt_count           0
# coaching_institute      0
# daily_study_hours       0
# family_income           0
# parent_education        0
# location_type           0
# peer_pressure_level     0
# mental_health_issues    0
# admission_taken         0
# dropout                 0
# dtype: int64

# %%
jee.isna().sum()
# Out:
# jee_main_score             0
# jee_advanced_score         0
# mock_test_score_avg        0
# school_board               0
# class_12_percent           0
# attempt_count              0
# coaching_institute      1209
# daily_study_hours          0
# family_income              0
# parent_education           0
# location_type              0
# peer_pressure_level        0
# mental_health_issues       0
# admission_taken            0
# dropout                    0
# dtype: int64

# %%
jee[jee["coaching_institute"].isna()]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 7              82.74               73.80                58.62         CBSE
# 9              79.60               63.74                77.82        State
# 10             65.51               91.57                79.06         CBSE
# 15             64.13               57.81                68.50         CBSE
# 17             76.40               98.67                73.50        State
# ...              ...                 ...                  ...          ...
# 4973           42.80               75.66                64.51         CBSE
# 4975           52.77               57.33                63.99         CBSE
# 4980           55.23               58.87                53.67        State
# 4994           62.80               85.11                64.35        State
# 4997          100.00               54.71                83.75         CBSE
#
# ...

# %% [markdown]
# #### TO get rows that have a NaN value in coaching institute

# %%
jee[jee["coaching_institute"].notna()]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              70.06               58.75                64.33        State
# 2              81.07               37.27                60.83         ICSE
# 3              93.32               60.72                69.33         ICSE
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4993           79.93               42.02                70.89         ICSE
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
# ...
