# %%
import pandas as pd
import numpy as np
jee = pd.read_csv('JEE_Dropout_After_Class_12.csv',delimiter=',')

# %%
jee.loc[jee['jee_main_score']==100, ['class_12_percent','attempt_count']]
# Out:
#       class_12_percent  attempt_count
# 113              67.05              1
# 125              76.06              2
# 179              57.81              1
# 209              76.67              2
# 220              67.45              1
# ...                ...            ...
# 4851             78.72              2
# 4855             85.22              2
# 4870             68.25              2
# 4989             71.27              2
# 4997             77.87              2
#
# [112 rows x 2 columns]

# %% [markdown]
# ### Can also be done as

# %%
jee[jee['attempt_count']>1]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 9              79.60               63.74                77.82        State
# 12             75.39               66.14                52.21         CBSE
# 13             45.21               62.20                62.41         ICSE
# 14             47.85               67.23                77.88        State
# 15             64.13               57.81                68.50         CBSE
# ...              ...                 ...                  ...          ...
# 4990           42.61               88.94                84.21         CBSE
# 4992           70.39               76.59                70.55        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4999           60.13               76.31                66.15        State
#
# ...

# %%
jee[jee['attempt_count']>1]['mental_health_issues']
# Out:
# 9       Yes
# 12       No
# 13      Yes
# 14      Yes
# 15       No
#        ...
# 4990     No
# 4992    Yes
# 4996    Yes
# 4997    Yes
# 4999    Yes
# Name: mental_health_issues, Length: 2523, dtype: object

# %%
jee[(jee['attempt_count']>1) & (jee['mental_health_issues']=='Yes')][['daily_study_hours','peer_pressure_level']]
# Out:
#       daily_study_hours peer_pressure_level
# 9                   2.7                High
# 13                  7.3              Medium
# 14                  3.1              Medium
# 19                  3.3              Medium
# 23                  2.0                High
# ...                 ...                 ...
# 4985                0.0                High
# 4992                3.9              Medium
# 4996                4.7                High
# 4997                6.3              Medium
# 4999                2.1                 Low
#
# [1202 rows x 2 columns]

# %% [markdown]
# ### Use double brackets when selecting multiple columns to be shown

# %%
jee[jee['school_board'].str.contains("CBSE|State")]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              70.06               58.75                64.33        State
# 4              68.72               77.73                82.37         CBSE
# 5              68.72               45.61                58.75        State
# 6              94.11               82.78                80.01         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
# ...

# %% [markdown]
# ### '|' acts like an 'or' between 'CBSE' and 'State'

# %%
jee[jee['school_board'].str.contains("CBSE|State", case=False, regex=False)]
# Out:
# Empty DataFrame
# Columns: [jee_main_score, jee_advanced_score, mock_test_score_avg, school_board, class_12_percent, attempt_count, coaching_institute, daily_study_hours, family_income, parent_education, location_type, peer_pressure_level, mental_health_issues, admission_taken, dropout]
# Index: []

# %% [markdown]
# #### When 'regex' is turned off, the str.contains looks for EXACT CBSE|STATE and not CBSE "OR" STATE

# %%
jee[jee['coaching_institute'].isin(['FIITJEE','Aakash','Allen']) & (jee['jee_main_score']==100.0)].head()
# Out:
#      jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 179           100.0               66.25                81.42        State
# 209           100.0               67.00                59.74         CBSE
# 234           100.0               70.93                50.12         ICSE
# 378           100.0               75.74                65.94         CBSE
# 420           100.0               66.54                80.68         CBSE
#
#      class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 179             57.81              1              Allen                2.1
# 209             76.67              2            FIITJEE                6.6
# 234             83.53              1              Allen                4.9
# 378             71.40              2              Allen                4.8
# 420             67.17              1              Allen                7.5
#
# ...

# %%
jee[jee['coaching_institute'].str.contains('Aakash') & (jee['jee_main_score']==100.0)]
# Out:
# Empty DataFrame
# Columns: [jee_main_score, jee_advanced_score, mock_test_score_avg, school_board, class_12_percent, attempt_count, coaching_institute, daily_study_hours, family_income, parent_education, location_type, peer_pressure_level, mental_health_issues, admission_taken, dropout]
# Index: []

# %% [markdown]
# ### None from Allen

# %%
jee[jee['jee_main_score']==100]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 113            100.0               43.53                69.07        State
# 125            100.0               55.06                66.47        State
# 179            100.0               66.25                81.42        State
# 209            100.0               67.00                59.74         CBSE
# 220            100.0               94.56                83.79        State
# ...              ...                 ...                  ...          ...
# 4851           100.0               63.50                47.60         CBSE
# 4855           100.0               75.47                69.37         CBSE
# 4870           100.0               66.94                71.92         CBSE
# 4989           100.0               53.67                64.19        State
# 4997           100.0               54.71                83.75         CBSE
#
# ...

# %%
jee.query('coaching_institute == "Allen" and jee_main_score == 100.0 and jee_advanced_score > 85')
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 1911           100.0               87.43                52.22         ICSE
# 1957           100.0               94.90                72.76        State
# 2549           100.0               92.88                81.90         CBSE
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 1911             75.41              1              Allen                7.3
# 1957             72.06              2              Allen                6.1
# 2549             89.17              2              Allen                0.8
#
#      family_income parent_education location_type peer_pressure_level  \
# 1911          High         Graduate         Rural                High
# 1957          High         Graduate    Semi-Urban              Medium
# 2549           Low               PG    Semi-Urban                 Low
#
#      mental_health_issues admission_taken  dropout
# ...
