# %%
import pandas as pd
import numpy as np
jee = pd.read_csv('JEE_Dropout_After_Class_12.csv',delimiter=',')

# %%
jee["jee_advanced_score"]
# Out:
# 0       59.22
# 1       58.75
# 2       37.27
# 3       60.72
# 4       77.73
#         ...
# 4995    86.82
# 4996    34.03
# 4997    54.71
# 4998    73.93
# 4999    76.31
# Name: jee_advanced_score, Length: 5000, dtype: float64

# %%
jee.school_board
# Out:
# 0        CBSE
# 1       State
# 2        ICSE
# 3        ICSE
# 4        CBSE
#         ...
# 4995    State
# 4996     CBSE
# 4997     CBSE
# 4998     CBSE
# 4999    State
# Name: school_board, Length: 5000, dtype: object

# %%
jee.sort_values(["jee_main_score","jee_advanced_score"], ascending=[0,1])
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 2305          100.00               17.29                59.83        State
# 1233          100.00               26.19                66.27         CBSE
# 880           100.00               27.54                57.79         ICSE
# 1924          100.00               33.48                62.04         ICSE
# 4186          100.00               38.65                73.29        State
# ...              ...                 ...                  ...          ...
# 4198           29.89               26.20                69.21         CBSE
# 2024           29.73               84.20                79.59         ICSE
# 4725           27.61               61.21                95.65         ICSE
# 4779           27.53               71.90                62.12         ICSE
# 262            26.62               70.36                75.09        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 2305             81.92              1            FIITJEE                6.2
# 1233             75.34              2                NaN                6.0
# 880              95.99              1            FIITJEE                3.2
# 1924             78.33              2              Local                1.7
# 4186             60.75              1              Allen                4.6
# ...                ...            ...                ...                ...
# 4198             92.55              2              Allen                7.3
# 2024             72.36              1              Local                5.1
# 4725             81.77              1              Local                5.0
# 4779             68.95              2            FIITJEE                5.1
# 262              82.30              1              Allen                2.7
#
#      family_income parent_education location_type peer_pressure_level  \
# 2305           Low         Graduate         Rural                 Low
# 1233          High               PG         Rural              Medium
# 880           High         Graduate         Urban              Medium
# 1924           Low        Upto 10th         Urban                 Low
# 4186           Mid               PG         Urban                 Low
# ...            ...              ...           ...                 ...
# 4198          High               PG         Rural                High
# 2024           Low         Graduate    Semi-Urban                High
# 4725           Low         Graduate         Urban                 Low
# 4779           Low        Upto 10th    Semi-Urban              Medium
# 262           High        Upto 10th    Semi-Urban                High
#
#      mental_health_issues admission_taken  dropout
# 2305                  Yes             Yes        0
# 1233                   No             Yes        0
# 880                   Yes              No        0
# 1924                  Yes             Yes        0
# 4186                   No             Yes        0
# ...                   ...             ...      ...
# 4198                  Yes              No        1
# 2024                   No             Yes        0
# 4725                   No              No        1
# 4779                  Yes              No        1
# 262                   Yes             Yes        0
#
# [5000 rows x 15 columns]

# %%
jee.sort_values(["jee_main_score","jee_advanced_score"], ascending=False).loc[0:,["coaching_institute","school_board","mental_health_issues","jee_main_score","jee_advanced_score"]]
# Out:
#      coaching_institute school_board mental_health_issues  jee_main_score  \
# 0               FIITJEE         CBSE                   No           78.95
# 1113            FIITJEE        State                   No           78.94
# 4741              Allen        State                  Yes           78.94
# 4312            FIITJEE         ICSE                  Yes           78.93
# 4206              Local         CBSE                   No           78.92
# ...                 ...          ...                  ...             ...
# 4198              Allen         CBSE                  Yes           29.89
# 2024              Local         ICSE                   No           29.73
# 4725              Local         ICSE                   No           27.61
# 4779            FIITJEE         ICSE                  Yes           27.53
# 262               Allen        State                  Yes           26.62
#
#       jee_advanced_score
# 0                  59.22
# 1113               52.03
# 4741               47.36
# 4312               83.25
# 4206               82.84
# ...                  ...
# 4198               26.20
# 2024               84.20
# 4725               61.21
# 4779               71.90
# 262                70.36
#
# [3442 rows x 5 columns]

# %% [markdown]
# #### It first sorts according to jee_main_score, and if there are values that are the same, it sorts according to jee_advanced_score

# %%
jee[jee.isnull().any(axis=1)]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 7              82.74               73.80                58.62         CBSE
# 9              79.60               63.74                77.82        State
# 10             65.51               91.57                79.06         CBSE
# 15             64.13               57.81                68.50         CBSE
# 17             76.40               98.67                73.50        State
# ...              ...                 ...                  ...          ...
# 4973           42.80               75.66                64.51         CBSE
# 4975           52.77               57.33                63.99         CBSE
# 4980           55.23               58.87                53.67        State
# 4994           62.80               85.11                64.35        State
# 4997          100.00               54.71                83.75         CBSE
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 7                77.15              1                NaN                2.2
# 9                94.96              2                NaN                2.7
# 10               66.88              1                NaN                5.5
# 15               74.68              2                NaN                6.0
# 17               78.29              1                NaN                4.0
# ...                ...            ...                ...                ...
# 4973             78.95              2                NaN                4.8
# 4975             68.00              2                NaN                3.6
# 4980             88.74              1                NaN                4.7
# 4994             89.05              1                NaN                0.6
# 4997             77.87              2                NaN                6.3
#
#      family_income parent_education location_type peer_pressure_level  \
# 7             High             12th         Urban                 Low
# 9              Mid             12th         Rural                High
# 10             Mid         Graduate         Urban                 Low
# 15            High         Graduate    Semi-Urban                 Low
# 17            High               PG         Rural                High
# ...            ...              ...           ...                 ...
# 4973          High               PG         Urban              Medium
# 4975           Mid        Upto 10th         Urban                 Low
# 4980           Mid             12th    Semi-Urban                 Low
# 4994          High             12th    Semi-Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
#
#      mental_health_issues admission_taken  dropout
# 7                      No             Yes        0
# 9                     Yes              No        0
# 10                     No             Yes        0
# 15                     No              No        0
# 17                    Yes             Yes        0
# ...                   ...             ...      ...
# 4973                   No             Yes        0
# 4975                  Yes             Yes        0
# 4980                  Yes              No        0
# 4994                  Yes             Yes        1
# 4997                  Yes             Yes        0
#
# [1209 rows x 15 columns]

# %% [markdown]
# ### This prints the rows that have NaN anywhere in the row

# %%
for index, row in jee.iterrows():
  print(index)
  print(row)
  print("\n\n")
# Out:
# 0
# jee_main_score              78.95
# jee_advanced_score          59.22
# mock_test_score_avg         59.86
# school_board                 CBSE
# class_12_percent            70.09
# attempt_count                   1
# coaching_institute        FIITJEE
# daily_study_hours             5.4
# family_income                 Low
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         1
# Name: 0, dtype: object
#
#
#
# 1
# jee_main_score              70.06
# jee_advanced_score          58.75
# mock_test_score_avg         64.33
# school_board                State
# class_12_percent             78.0
# attempt_count                   1
# coaching_institute        FIITJEE
# daily_study_hours             5.5
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues          Yes
# admission_taken                No
# dropout                         0
# Name: 1, dtype: object
#
#
#
# 2
# jee_main_score               81.07
# jee_advanced_score           37.27
# mock_test_score_avg          60.83
# school_board                  ICSE
# class_12_percent             64.36
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              7.0
# family_income                  Low
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          1
# Name: 2, dtype: object
#
#
#
# 3
# jee_main_score               93.32
# jee_advanced_score           60.72
# mock_test_score_avg          69.33
# school_board                  ICSE
# class_12_percent             73.21
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              2.1
# family_income                  Low
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 3, dtype: object
#
#
#
# 4
# jee_main_score               68.72
# jee_advanced_score           77.73
# mock_test_score_avg          82.37
# school_board                  CBSE
# class_12_percent             89.02
# attempt_count                    1
# coaching_institute           Allen
# daily_study_hours              6.3
# family_income                  Mid
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 4, dtype: object
#
#
#
# 5
# jee_main_score               68.72
# jee_advanced_score           45.61
# mock_test_score_avg          58.75
# school_board                 State
# class_12_percent             79.28
# attempt_count                    1
# coaching_institute           Local
# daily_study_hours              4.5
# family_income                  Mid
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 5, dtype: object
#
#
#
# 6
# jee_main_score               94.11
# jee_advanced_score           82.78
# mock_test_score_avg          80.01
# school_board                  CBSE
# class_12_percent             76.31
# attempt_count                    1
# coaching_institute           Local
# daily_study_hours              3.7
# family_income                  Mid
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 6, dtype: object
#
#
#
# 7
# jee_main_score          82.74
# jee_advanced_score       73.8
# mock_test_score_avg     58.62
# school_board             CBSE
# class_12_percent        77.15
# attempt_count               1
# coaching_institute        NaN
# daily_study_hours         2.2
# family_income            High
# parent_education         12th
# location_type           Urban
# peer_pressure_level       Low
# mental_health_issues       No
# admission_taken           Yes
# dropout                     0
# Name: 7, dtype: object
#
#
#
# 8
# jee_main_score               65.43
# jee_advanced_score           54.25
# mock_test_score_avg          57.83
# school_board                  ICSE
# class_12_percent             71.11
# attempt_count                    1
# coaching_institute           Local
# daily_study_hours              5.7
# family_income                  Mid
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 8, dtype: object
#
#
#
# 9
# jee_main_score           79.6
# jee_advanced_score      63.74
# mock_test_score_avg     77.82
# school_board            State
# class_12_percent        94.96
# attempt_count               2
# coaching_institute        NaN
# daily_study_hours         2.7
# family_income             Mid
# parent_education         12th
# location_type           Rural
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken            No
# dropout                     0
# Name: 9, dtype: object
#
#
#
# 10
# jee_main_score             65.51
# jee_advanced_score         91.57
# mock_test_score_avg        79.06
# school_board                CBSE
# class_12_percent           66.88
# attempt_count                  1
# coaching_institute           NaN
# daily_study_hours            5.5
# family_income                Mid
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level          Low
# mental_health_issues          No
# admission_taken              Yes
# dropout                        0
# Name: 10, dtype: object
#
#
#
# 11
# jee_main_score               65.48
# jee_advanced_score           77.74
# mock_test_score_avg          78.22
# school_board                  ICSE
# class_12_percent             77.11
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              8.4
# family_income                 High
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 11, dtype: object
#
#
#
# 12
# jee_main_score           75.39
# jee_advanced_score       66.14
# mock_test_score_avg      52.21
# school_board              CBSE
# class_12_percent         76.15
# attempt_count                2
# coaching_institute       Allen
# daily_study_hours          6.5
# family_income              Mid
# parent_education          12th
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues        No
# admission_taken            Yes
# dropout                      0
# Name: 12, dtype: object
#
#
#
# 13
# jee_main_score             45.21
# jee_advanced_score          62.2
# mock_test_score_avg        62.41
# school_board                ICSE
# class_12_percent           85.09
# attempt_count                  2
# coaching_institute         Allen
# daily_study_hours            7.3
# family_income                Low
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken               No
# dropout                        1
# Name: 13, dtype: object
#
#
#
# 14
# jee_main_score           47.85
# jee_advanced_score       67.23
# mock_test_score_avg      77.88
# school_board             State
# class_12_percent         86.03
# attempt_count                2
# coaching_institute       Local
# daily_study_hours          3.1
# family_income              Low
# parent_education          12th
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken             No
# dropout                      1
# Name: 14, dtype: object
#
#
#
# 15
# jee_main_score               64.13
# jee_advanced_score           57.81
# mock_test_score_avg           68.5
# school_board                  CBSE
# class_12_percent             74.68
# attempt_count                    2
# coaching_institute             NaN
# daily_study_hours              6.0
# family_income                 High
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                 No
# dropout                          0
# Name: 15, dtype: object
#
#
#
# 16
# jee_main_score            57.82
# jee_advanced_score        32.32
# mock_test_score_avg       55.12
# school_board              State
# class_12_percent          77.91
# attempt_count                 1
# coaching_institute      FIITJEE
# daily_study_hours           2.2
# family_income              High
# parent_education             PG
# location_type             Rural
# peer_pressure_level      Medium
# mental_health_issues         No
# admission_taken             Yes
# dropout                       0
# Name: 16, dtype: object
#
#
#
# 17
# jee_main_score           76.4
# jee_advanced_score      98.67
# mock_test_score_avg      73.5
# school_board            State
# class_12_percent        78.29
# attempt_count               1
# coaching_institute        NaN
# daily_study_hours         4.0
# family_income            High
# parent_education           PG
# location_type           Rural
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken           Yes
# dropout                     0
# Name: 17, dtype: object
#
#
#
# 18
# jee_main_score            59.29
# jee_advanced_score        68.49
# mock_test_score_avg       59.42
# school_board               ICSE
# class_12_percent          52.28
# attempt_count                 1
# coaching_institute      FIITJEE
# daily_study_hours           8.0
# family_income              High
# parent_education           12th
# location_type             Urban
# peer_pressure_level         Low
# mental_health_issues         No
# admission_taken              No
# dropout                       0
# Name: 18, dtype: object
#
#
#
# 19
# jee_main_score              52.23
# jee_advanced_score          72.37
# mock_test_score_avg         89.53
# school_board                 CBSE
# class_12_percent            59.11
# attempt_count                   2
# coaching_institute            NaN
# daily_study_hours             3.3
# family_income                High
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level        Medium
# mental_health_issues          Yes
# admission_taken                No
# dropout                         0
# Name: 19, dtype: object
#
#
#
# 20
# jee_main_score           92.52
# jee_advanced_score       65.07
# mock_test_score_avg      86.54
# school_board              CBSE
# class_12_percent         68.95
# attempt_count                1
# coaching_institute       Local
# daily_study_hours          6.7
# family_income              Mid
# parent_education          12th
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken             No
# dropout                      0
# Name: 20, dtype: object
#
#
#
# 21
# jee_main_score          68.84
# jee_advanced_score      54.24
# mock_test_score_avg     75.25
# school_board             ICSE
# class_12_percent        69.38
# attempt_count               1
# coaching_institute      Local
# daily_study_hours         6.5
# family_income             Low
# parent_education           PG
# location_type           Urban
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken            No
# dropout                     1
# Name: 21, dtype: object
#
#
#
# 22
# jee_main_score               72.95
# jee_advanced_score           63.03
# mock_test_score_avg          84.33
# school_board                  ICSE
# class_12_percent             63.01
# attempt_count                    2
# coaching_institute             NaN
# daily_study_hours              6.6
# family_income                  Low
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                 No
# dropout                          1
# Name: 22, dtype: object
#
#
#
# 23
# jee_main_score          52.05
# jee_advanced_score      40.41
# mock_test_score_avg     68.78
# school_board            State
# class_12_percent         82.5
# attempt_count               2
# coaching_institute      Allen
# daily_study_hours         2.0
# family_income             Mid
# parent_education           PG
# location_type           Rural
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken           Yes
# dropout                     0
# Name: 23, dtype: object
#
#
#
# 24
# jee_main_score               64.38
# jee_advanced_score           100.0
# mock_test_score_avg          77.19
# school_board                  CBSE
# class_12_percent             75.02
# attempt_count                    2
# coaching_institute         FIITJEE
# daily_study_hours              5.6
# family_income                 High
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 24, dtype: object
#
#
#
# 25
# jee_main_score              73.55
# jee_advanced_score          46.25
# mock_test_score_avg         85.73
# school_board                 CBSE
# class_12_percent            72.85
# attempt_count                   2
# coaching_institute          Allen
# daily_study_hours             4.2
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level        Medium
# mental_health_issues           No
# admission_taken               Yes
# dropout                         0
# Name: 25, dtype: object
#
#
#
# 26
# jee_main_score               55.89
# jee_advanced_score           49.49
# mock_test_score_avg          70.95
# school_board                  ICSE
# class_12_percent             62.44
# attempt_count                    2
# coaching_institute           Allen
# daily_study_hours              6.7
# family_income                 High
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 26, dtype: object
#
#
#
# 27
# jee_main_score          77.26
# jee_advanced_score      58.96
# mock_test_score_avg     64.94
# school_board             ICSE
# class_12_percent        74.55
# attempt_count               1
# coaching_institute        NaN
# daily_study_hours         1.2
# family_income             Low
# parent_education           PG
# location_type           Rural
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken            No
# dropout                     1
# Name: 27, dtype: object
#
#
#
# 28
# jee_main_score             63.59
# jee_advanced_score         86.61
# mock_test_score_avg        47.54
# school_board                ICSE
# class_12_percent            50.0
# attempt_count                  2
# coaching_institute       FIITJEE
# daily_study_hours            5.2
# family_income                Low
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level          Low
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 28, dtype: object
#
#
#
# 29
# jee_main_score               67.92
# jee_advanced_score           66.23
# mock_test_score_avg           67.0
# school_board                  CBSE
# class_12_percent             73.37
# attempt_count                    2
# coaching_institute         FIITJEE
# daily_study_hours              5.0
# family_income                 High
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                 No
# dropout                          0
# Name: 29, dtype: object
#
#
#
# 30
# jee_main_score               63.58
# jee_advanced_score           46.22
# mock_test_score_avg          77.88
# school_board                  CBSE
# class_12_percent             75.63
# attempt_count                    1
# coaching_institute           Local
# daily_study_hours              0.5
# family_income                  Mid
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                 No
# dropout                          0
# Name: 30, dtype: object
#
#
#
# 31
# jee_main_score              97.93
# jee_advanced_score          86.07
# mock_test_score_avg         79.35
# school_board                State
# class_12_percent            77.42
# attempt_count                   1
# coaching_institute            NaN
# daily_study_hours             2.7
# family_income                High
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level          High
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 31, dtype: object
#
#
#
# 32
# jee_main_score              71.81
# jee_advanced_score           77.7
# mock_test_score_avg         74.05
# school_board                 ICSE
# class_12_percent            59.36
# attempt_count                   1
# coaching_institute            NaN
# daily_study_hours             0.8
# family_income                High
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues          Yes
# admission_taken               Yes
# dropout                         0
# Name: 32, dtype: object
#
#
#
# 33
# jee_main_score           57.19
# jee_advanced_score       74.61
# mock_test_score_avg       61.5
# school_board             State
# class_12_percent         77.25
# attempt_count                2
# coaching_institute         NaN
# daily_study_hours          3.0
# family_income              Low
# parent_education            PG
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues        No
# admission_taken            Yes
# dropout                      0
# Name: 33, dtype: object
#
#
#
# 34
# jee_main_score             83.52
# jee_advanced_score         77.45
# mock_test_score_avg        44.28
# school_board                CBSE
# class_12_percent           64.59
# attempt_count                  2
# coaching_institute         Local
# daily_study_hours            5.6
# family_income               High
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level         High
# mental_health_issues          No
# admission_taken               No
# dropout                        0
# Name: 34, dtype: object
#
#
#
# 35
# jee_main_score               54.91
# jee_advanced_score           100.0
# mock_test_score_avg          62.06
# school_board                 State
# class_12_percent             66.88
# attempt_count                    1
# coaching_institute           Local
# daily_study_hours              4.9
# family_income                  Mid
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 35, dtype: object
#
#
#
# 36
# jee_main_score            74.92
# jee_advanced_score        100.0
# mock_test_score_avg       64.35
# school_board              State
# class_12_percent          82.18
# attempt_count                 1
# coaching_institute      FIITJEE
# daily_study_hours           4.8
# family_income              High
# parent_education             PG
# location_type             Rural
# peer_pressure_level        High
# mental_health_issues         No
# admission_taken             Yes
# dropout                       0
# Name: 36, dtype: object
#
#
#
# 37
# jee_main_score               44.56
# jee_advanced_score           55.01
# mock_test_score_avg          64.24
# school_board                 State
# class_12_percent             95.14
# attempt_count                    2
# coaching_institute           Local
# daily_study_hours              2.4
# family_income                  Low
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          1
# Name: 37, dtype: object
#
#
#
# 38
# jee_main_score          53.41
# jee_advanced_score      91.98
# mock_test_score_avg     75.42
# school_board             ICSE
# class_12_percent        75.51
# attempt_count               1
# coaching_institute        NaN
# daily_study_hours         6.7
# family_income             Mid
# parent_education           PG
# location_type           Urban
# peer_pressure_level       Low
# mental_health_issues       No
# admission_taken           Yes
# dropout                     0
# Name: 38, dtype: object
#
#
#
# 39
# jee_main_score             74.76
# jee_advanced_score         72.13
# mock_test_score_avg        91.83
# school_board                CBSE
# class_12_percent           66.83
# attempt_count                  1
# coaching_institute           NaN
# daily_study_hours            4.5
# family_income                Mid
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 39, dtype: object
#
#
#
# 40
# jee_main_score          82.34
# jee_advanced_score      73.99
# mock_test_score_avg     69.48
# school_board             ICSE
# class_12_percent        76.89
# attempt_count               1
# coaching_institute      Allen
# daily_study_hours         4.6
# family_income             Low
# parent_education         12th
# location_type           Urban
# peer_pressure_level       Low
# mental_health_issues      Yes
# admission_taken           Yes
# dropout                     0
# Name: 40, dtype: object
#
#
#
# 41
# jee_main_score           74.4
# jee_advanced_score      38.92
# mock_test_score_avg      65.4
# school_board            State
# class_12_percent        84.39
# attempt_count               1
# coaching_institute      Local
# daily_study_hours         6.4
# family_income             Low
# parent_education         12th
# location_type           Urban
# peer_pressure_level       Low
# mental_health_issues       No
# admission_taken            No
# dropout                     1
# Name: 41, dtype: object
#
#
#
# 42
# jee_main_score              70.38
# jee_advanced_score          63.27
# mock_test_score_avg         64.89
# school_board                 ICSE
# class_12_percent            81.21
# attempt_count                   2
# coaching_institute            NaN
# daily_study_hours             2.5
# family_income                High
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken               Yes
# dropout                         0
# Name: 42, dtype: object
#
#
#
# 43
# jee_main_score               67.78
# jee_advanced_score           52.99
# mock_test_score_avg          69.49
# school_board                  CBSE
# class_12_percent             100.0
# attempt_count                    2
# coaching_institute             NaN
# daily_study_hours              5.0
# family_income                  Low
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 43, dtype: object
#
#
#
# 44
# jee_main_score                51.3
# jee_advanced_score           79.25
# mock_test_score_avg          58.06
# school_board                  CBSE
# class_12_percent             67.85
# attempt_count                    2
# coaching_institute         FIITJEE
# daily_study_hours              5.3
# family_income                  Low
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 44, dtype: object
#
#
#
# 45
# jee_main_score           61.92
# jee_advanced_score       83.14
# mock_test_score_avg      69.44
# school_board             State
# class_12_percent         77.52
# attempt_count                1
# coaching_institute       Local
# daily_study_hours          3.4
# family_income              Low
# parent_education            PG
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken            Yes
# dropout                      0
# Name: 45, dtype: object
#
#
#
# 46
# jee_main_score               65.55
# jee_advanced_score           32.81
# mock_test_score_avg          73.41
# school_board                 State
# class_12_percent             90.49
# attempt_count                    2
# coaching_institute             NaN
# daily_study_hours              5.8
# family_income                  Low
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          1
# Name: 46, dtype: object
#
#
#
# 47
# jee_main_score                86.8
# jee_advanced_score           65.65
# mock_test_score_avg          70.52
# school_board                  ICSE
# class_12_percent             89.86
# attempt_count                    2
# coaching_institute         FIITJEE
# daily_study_hours              5.5
# family_income                  Mid
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                 No
# dropout                          0
# Name: 47, dtype: object
#
#
#
# 48
# jee_main_score             76.81
# jee_advanced_score         83.95
# mock_test_score_avg        73.49
# school_board                CBSE
# class_12_percent            55.5
# attempt_count                  1
# coaching_institute         Allen
# daily_study_hours            4.3
# family_income                Mid
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level          Low
# mental_health_issues          No
# admission_taken              Yes
# dropout                        0
# Name: 48, dtype: object
#
#
#
# 49
# jee_main_score               47.32
# jee_advanced_score           63.01
# mock_test_score_avg           73.2
# school_board                  CBSE
# class_12_percent             74.97
# attempt_count                    1
# coaching_institute           Allen
# daily_study_hours              4.2
# family_income                  Mid
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 49, dtype: object
#
#
#
# 50
# jee_main_score               76.54
# jee_advanced_score           77.67
# mock_test_score_avg          46.74
# school_board                  ICSE
# class_12_percent             89.85
# attempt_count                    2
# coaching_institute         FIITJEE
# daily_study_hours              5.5
# family_income                  Low
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 50, dtype: object
#
#
#
# 51
# jee_main_score              66.61
# jee_advanced_score          71.62
# mock_test_score_avg         75.64
# school_board                 CBSE
# class_12_percent            100.0
# attempt_count                   1
# coaching_institute          Local
# daily_study_hours             6.1
# family_income                High
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 51, dtype: object
#
#
#
# 52
# jee_main_score             62.52
# jee_advanced_score         71.47
# mock_test_score_avg        59.95
# school_board               State
# class_12_percent           82.04
# attempt_count                  1
# coaching_institute           NaN
# daily_study_hours            4.6
# family_income               High
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level         High
# mental_health_issues          No
# admission_taken              Yes
# dropout                        0
# Name: 52, dtype: object
#
#
#
# 53
# jee_main_score               80.56
# jee_advanced_score           61.66
# mock_test_score_avg          54.85
# school_board                 State
# class_12_percent             71.32
# attempt_count                    2
# coaching_institute           Local
# daily_study_hours              6.7
# family_income                 High
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 53, dtype: object
#
#
#
# 54
# jee_main_score            86.43
# jee_advanced_score        46.53
# mock_test_score_avg       54.75
# school_board               ICSE
# class_12_percent          64.91
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           5.8
# family_income              High
# parent_education           12th
# location_type             Rural
# peer_pressure_level      Medium
# mental_health_issues        Yes
# admission_taken             Yes
# dropout                       0
# Name: 54, dtype: object
#
#
#
# 55
# jee_main_score               85.04
# jee_advanced_score           48.06
# mock_test_score_avg           73.2
# school_board                  ICSE
# class_12_percent             97.19
# attempt_count                    2
# coaching_institute             NaN
# daily_study_hours              0.9
# family_income                  Mid
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 55, dtype: object
#
#
#
# 56
# jee_main_score          60.25
# jee_advanced_score      77.35
# mock_test_score_avg     65.33
# school_board             ICSE
# class_12_percent        82.29
# attempt_count               1
# coaching_institute        NaN
# daily_study_hours         1.7
# family_income            High
# parent_education         12th
# location_type           Urban
# peer_pressure_level      High
# mental_health_issues       No
# admission_taken           Yes
# dropout                     1
# Name: 56, dtype: object
#
#
#
# 57
# jee_main_score              67.67
# jee_advanced_score          66.31
# mock_test_score_avg         47.82
# school_board                State
# class_12_percent            66.52
# attempt_count                   1
# coaching_institute            NaN
# daily_study_hours             6.9
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level        Medium
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 57, dtype: object
#
#
#
# 58
# jee_main_score             76.64
# jee_advanced_score         63.78
# mock_test_score_avg        73.74
# school_board                ICSE
# class_12_percent           72.97
# attempt_count                  1
# coaching_institute         Local
# daily_study_hours            4.0
# family_income               High
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken               No
# dropout                        0
# Name: 58, dtype: object
#
#
#
# 59
# jee_main_score             85.66
# jee_advanced_score         59.22
# mock_test_score_avg        50.72
# school_board                CBSE
# class_12_percent            78.1
# attempt_count                  1
# coaching_institute         Local
# daily_study_hours            4.8
# family_income               High
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level       Medium
# mental_health_issues          No
# admission_taken              Yes
# dropout                        0
# Name: 59, dtype: object
#
#
#
# 60
# jee_main_score             65.29
# jee_advanced_score         61.12
# mock_test_score_avg        69.68
# school_board                ICSE
# class_12_percent           80.44
# attempt_count                  1
# coaching_institute       FIITJEE
# daily_study_hours            6.8
# family_income                Mid
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level          Low
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 60, dtype: object
#
#
#
# 61
# jee_main_score           69.4
# jee_advanced_score      82.75
# mock_test_score_avg     70.86
# school_board             CBSE
# class_12_percent         66.0
# attempt_count               1
# coaching_institute      Allen
# daily_study_hours         4.5
# family_income             Mid
# parent_education         12th
# location_type           Urban
# peer_pressure_level       Low
# mental_health_issues      Yes
# admission_taken           Yes
# dropout                     0
# Name: 61, dtype: object
#
#
#
# 62
# jee_main_score            56.51
# jee_advanced_score        60.64
# mock_test_score_avg       78.63
# school_board              State
# class_12_percent          68.86
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           4.6
# family_income              High
# parent_education           12th
# location_type             Rural
# peer_pressure_level      Medium
# mental_health_issues        Yes
# admission_taken              No
# dropout                       0
# Name: 62, dtype: object
#
#
#
# 63
# jee_main_score           55.25
# jee_advanced_score       44.54
# mock_test_score_avg      89.38
# school_board              CBSE
# class_12_percent         58.47
# attempt_count                2
# coaching_institute         NaN
# daily_study_hours          2.8
# family_income              Low
# parent_education            PG
# location_type            Urban
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken            Yes
# dropout                      0
# Name: 63, dtype: object
#
#
#
# 64
# jee_main_score               83.38
# jee_advanced_score            77.9
# mock_test_score_avg          51.62
# school_board                  CBSE
# class_12_percent              85.4
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              5.2
# family_income                 High
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 64, dtype: object
#
#
#
# 65
# jee_main_score               90.99
# jee_advanced_score           62.72
# mock_test_score_avg          67.37
# school_board                  CBSE
# class_12_percent             71.58
# attempt_count                    2
# coaching_institute           Allen
# daily_study_hours              5.7
# family_income                 High
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 65, dtype: object
#
#
#
# 66
# jee_main_score               70.99
# jee_advanced_score            66.5
# mock_test_score_avg          64.68
# school_board                 State
# class_12_percent             79.66
# attempt_count                    2
# coaching_institute         FIITJEE
# daily_study_hours              3.3
# family_income                 High
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 66, dtype: object
#
#
#
# 67
# jee_main_score               86.05
# jee_advanced_score           91.72
# mock_test_score_avg           73.2
# school_board                  CBSE
# class_12_percent             89.22
# attempt_count                    2
# coaching_institute           Allen
# daily_study_hours              2.7
# family_income                  Mid
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 67, dtype: object
#
#
#
# 68
# jee_main_score           77.06
# jee_advanced_score       65.67
# mock_test_score_avg      70.59
# school_board              CBSE
# class_12_percent          77.2
# attempt_count                1
# coaching_institute       Allen
# daily_study_hours          9.8
# family_income             High
# parent_education          12th
# location_type            Urban
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken            Yes
# dropout                      0
# Name: 68, dtype: object
#
#
#
# 69
# jee_main_score             62.97
# jee_advanced_score         70.63
# mock_test_score_avg        63.77
# school_board                ICSE
# class_12_percent           73.87
# attempt_count                  2
# coaching_institute           NaN
# daily_study_hours            4.3
# family_income                Low
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level          Low
# mental_health_issues          No
# admission_taken               No
# dropout                        1
# Name: 69, dtype: object
#
#
#
# 70
# jee_main_score             77.06
# jee_advanced_score         47.14
# mock_test_score_avg        62.71
# school_board                ICSE
# class_12_percent           76.94
# attempt_count                  2
# coaching_institute         Allen
# daily_study_hours            3.1
# family_income               High
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 70, dtype: object
#
#
#
# 71
# jee_main_score          93.53
# jee_advanced_score      62.49
# mock_test_score_avg      54.6
# school_board             ICSE
# class_12_percent        75.63
# attempt_count               1
# coaching_institute      Local
# daily_study_hours         5.9
# family_income             Low
# parent_education         12th
# location_type           Urban
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken           Yes
# dropout                     0
# Name: 71, dtype: object
#
#
#
# 72
# jee_main_score                71.5
# jee_advanced_score           75.75
# mock_test_score_avg          79.85
# school_board                  CBSE
# class_12_percent             87.46
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              4.4
# family_income                  Low
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          1
# Name: 72, dtype: object
#
#
#
# 73
# jee_main_score              93.91
# jee_advanced_score          41.11
# mock_test_score_avg         73.51
# school_board                 CBSE
# class_12_percent            78.11
# attempt_count                   1
# coaching_institute        FIITJEE
# daily_study_hours             2.3
# family_income                 Low
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level          High
# mental_health_issues          Yes
# admission_taken                No
# dropout                         1
# Name: 73, dtype: object
#
#
#
# 74
# jee_main_score           35.32
# jee_advanced_score       69.21
# mock_test_score_avg      79.01
# school_board             State
# class_12_percent         69.56
# attempt_count                2
# coaching_institute       Local
# daily_study_hours          5.5
# family_income             High
# parent_education          12th
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken            Yes
# dropout                      0
# Name: 74, dtype: object
#
#
#
# 75
# jee_main_score           83.51
# jee_advanced_score       67.61
# mock_test_score_avg      64.28
# school_board              CBSE
# class_12_percent         85.48
# attempt_count                2
# coaching_institute       Local
# daily_study_hours          2.8
# family_income              Mid
# parent_education            PG
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken            Yes
# dropout                      0
# Name: 75, dtype: object
#
#
#
# 76
# jee_main_score           73.22
# jee_advanced_score       66.66
# mock_test_score_avg      60.12
# school_board              CBSE
# class_12_percent          87.3
# attempt_count                2
# coaching_institute         NaN
# daily_study_hours          7.7
# family_income              Mid
# parent_education          12th
# location_type            Rural
# peer_pressure_level     Medium
# mental_health_issues        No
# admission_taken             No
# dropout                      0
# Name: 76, dtype: object
#
#
#
# 77
# jee_main_score             67.81
# jee_advanced_score         82.59
# mock_test_score_avg        55.06
# school_board               State
# class_12_percent           61.62
# attempt_count                  1
# coaching_institute       FIITJEE
# daily_study_hours            5.5
# family_income               High
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken               No
# dropout                        0
# Name: 77, dtype: object
#
#
#
# 78
# jee_main_score             73.28
# jee_advanced_score         71.35
# mock_test_score_avg        72.31
# school_board                CBSE
# class_12_percent           90.33
# attempt_count                  1
# coaching_institute         Local
# daily_study_hours            3.9
# family_income               High
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level         High
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 78, dtype: object
#
#
#
# 79
# jee_main_score             44.17
# jee_advanced_score         89.65
# mock_test_score_avg        55.52
# school_board               State
# class_12_percent           78.65
# attempt_count                  1
# coaching_institute           NaN
# daily_study_hours            4.7
# family_income                Low
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level          Low
# mental_health_issues          No
# admission_taken               No
# dropout                        1
# Name: 79, dtype: object
#
#
#
# 80
# jee_main_score            68.92
# jee_advanced_score         50.1
# mock_test_score_avg       90.18
# school_board              State
# class_12_percent          77.83
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           6.3
# family_income              High
# parent_education             PG
# location_type             Rural
# peer_pressure_level         Low
# mental_health_issues         No
# admission_taken              No
# dropout                       0
# Name: 80, dtype: object
#
#
#
# 81
# jee_main_score             77.0
# jee_advanced_score        68.17
# mock_test_score_avg       52.31
# school_board               ICSE
# class_12_percent          85.07
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           4.9
# family_income               Mid
# parent_education           12th
# location_type             Urban
# peer_pressure_level      Medium
# mental_health_issues         No
# admission_taken             Yes
# dropout                       0
# Name: 81, dtype: object
#
#
#
# 82
# jee_main_score           92.69
# jee_advanced_score       67.35
# mock_test_score_avg      71.28
# school_board              CBSE
# class_12_percent         69.33
# attempt_count                2
# coaching_institute       Local
# daily_study_hours          8.7
# family_income             High
# parent_education            PG
# location_type            Urban
# peer_pressure_level     Medium
# mental_health_issues       Yes
# admission_taken            Yes
# dropout                      0
# Name: 82, dtype: object
#
#
#
# 83
# jee_main_score               64.74
# jee_advanced_score           48.89
# mock_test_score_avg           86.8
# school_board                  ICSE
# class_12_percent             84.54
# attempt_count                    1
# coaching_institute           Allen
# daily_study_hours              6.8
# family_income                 High
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 83, dtype: object
#
#
#
# 84
# jee_main_score              60.68
# jee_advanced_score           81.3
# mock_test_score_avg         75.19
# school_board                 CBSE
# class_12_percent            71.23
# attempt_count                   1
# coaching_institute          Allen
# daily_study_hours             5.5
# family_income                High
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level          High
# mental_health_issues           No
# admission_taken               Yes
# dropout                         0
# Name: 84, dtype: object
#
#
#
# 85
# jee_main_score             64.98
# jee_advanced_score         100.0
# mock_test_score_avg        70.11
# school_board                ICSE
# class_12_percent           60.25
# attempt_count                  2
# coaching_institute         Local
# daily_study_hours            2.6
# family_income                Low
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level       Medium
# mental_health_issues          No
# admission_taken               No
# dropout                        1
# Name: 85, dtype: object
#
#
#
# 86
# jee_main_score              84.82
# jee_advanced_score          65.73
# mock_test_score_avg         56.38
# school_board                State
# class_12_percent            65.02
# attempt_count                   2
# coaching_institute          Allen
# daily_study_hours             4.2
# family_income                High
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level        Medium
# mental_health_issues          Yes
# admission_taken                No
# dropout                         0
# Name: 86, dtype: object
#
#
#
# 87
# jee_main_score              76.6
# jee_advanced_score         74.08
# mock_test_score_avg        51.42
# school_board               State
# class_12_percent           80.67
# attempt_count                  2
# coaching_institute       FIITJEE
# daily_study_hours            5.5
# family_income               High
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level          Low
# mental_health_issues          No
# admission_taken               No
# dropout                        0
# Name: 87, dtype: object
#
#
#
# 88
# jee_main_score              64.58
# jee_advanced_score          67.35
# mock_test_score_avg         77.24
# school_board                State
# class_12_percent            65.55
# attempt_count                   1
# coaching_institute            NaN
# daily_study_hours             2.9
# family_income                High
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues          Yes
# admission_taken                No
# dropout                         0
# Name: 88, dtype: object
#
#
#
# 89
# jee_main_score          79.19
# jee_advanced_score      54.58
# mock_test_score_avg     86.07
# school_board            State
# class_12_percent         91.1
# attempt_count               2
# coaching_institute        NaN
# daily_study_hours         7.1
# family_income             Mid
# parent_education           PG
# location_type           Urban
# peer_pressure_level       Low
# mental_health_issues       No
# admission_taken            No
# dropout                     0
# Name: 89, dtype: object
#
#
#
# 90
# jee_main_score             73.36
# jee_advanced_score         36.87
# mock_test_score_avg        62.73
# school_board                CBSE
# class_12_percent           86.89
# attempt_count                  1
# coaching_institute         Local
# daily_study_hours            2.6
# family_income                Low
# parent_education        Graduate
# location_type              Urban
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 90, dtype: object
#
#
#
# 91
# jee_main_score               85.56
# jee_advanced_score           54.71
# mock_test_score_avg          54.33
# school_board                  CBSE
# class_12_percent             88.33
# ...
# school_board                 CBSE
# class_12_percent            77.78
# attempt_count                   2
# coaching_institute          Local
# daily_study_hours             6.5
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 4970, dtype: object
#
#
#
# 4971
# jee_main_score               70.87
# jee_advanced_score           77.22
# mock_test_score_avg          64.85
# school_board                 State
# class_12_percent              78.3
# attempt_count                    1
# coaching_institute             NaN
# daily_study_hours              3.4
# family_income                  Mid
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues            No
# admission_taken                Yes
# dropout                          0
# Name: 4971, dtype: object
#
#
#
# 4972
# jee_main_score            57.88
# jee_advanced_score        79.52
# mock_test_score_avg       83.53
# school_board               CBSE
# class_12_percent           65.9
# attempt_count                 1
# coaching_institute      FIITJEE
# daily_study_hours           2.6
# family_income               Mid
# parent_education           12th
# location_type             Rural
# peer_pressure_level         Low
# mental_health_issues        Yes
# admission_taken             Yes
# dropout                       0
# Name: 4972, dtype: object
#
#
#
# 4973
# jee_main_score            42.8
# jee_advanced_score       75.66
# mock_test_score_avg      64.51
# school_board              CBSE
# class_12_percent         78.95
# attempt_count                2
# coaching_institute         NaN
# daily_study_hours          4.8
# family_income             High
# parent_education            PG
# location_type            Urban
# peer_pressure_level     Medium
# mental_health_issues        No
# admission_taken            Yes
# dropout                      0
# Name: 4973, dtype: object
#
#
#
# 4974
# jee_main_score            51.39
# jee_advanced_score        90.25
# mock_test_score_avg       80.66
# school_board              State
# class_12_percent          72.33
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           4.1
# family_income              High
# parent_education           12th
# location_type             Rural
# peer_pressure_level      Medium
# mental_health_issues         No
# admission_taken              No
# dropout                       0
# Name: 4974, dtype: object
#
#
#
# 4975
# jee_main_score              52.77
# jee_advanced_score          57.33
# mock_test_score_avg         63.99
# school_board                 CBSE
# class_12_percent             68.0
# attempt_count                   2
# coaching_institute            NaN
# daily_study_hours             3.6
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues          Yes
# admission_taken               Yes
# dropout                         0
# Name: 4975, dtype: object
#
#
#
# 4976
# jee_main_score              91.3
# jee_advanced_score         92.79
# mock_test_score_avg        56.48
# school_board               State
# class_12_percent           82.87
# attempt_count                  1
# coaching_institute         Local
# daily_study_hours            4.9
# family_income                Mid
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level       Medium
# mental_health_issues         Yes
# admission_taken               No
# dropout                        0
# Name: 4976, dtype: object
#
#
#
# 4977
# jee_main_score          73.62
# jee_advanced_score      51.59
# mock_test_score_avg     72.38
# school_board             CBSE
# class_12_percent        67.23
# attempt_count               2
# coaching_institute      Allen
# daily_study_hours         2.1
# family_income             Low
# parent_education         12th
# location_type           Urban
# peer_pressure_level      High
# mental_health_issues       No
# admission_taken           Yes
# dropout                     0
# Name: 4977, dtype: object
#
#
#
# 4978
# jee_main_score            77.45
# jee_advanced_score         49.8
# mock_test_score_avg       54.74
# school_board               ICSE
# class_12_percent          70.43
# attempt_count                 1
# coaching_institute      FIITJEE
# daily_study_hours           1.1
# family_income              High
# parent_education           12th
# location_type             Urban
# peer_pressure_level        High
# mental_health_issues         No
# admission_taken             Yes
# dropout                       1
# Name: 4978, dtype: object
#
#
#
# 4979
# jee_main_score              40.91
# jee_advanced_score          37.84
# mock_test_score_avg         74.43
# school_board                State
# class_12_percent            75.72
# attempt_count                   1
# coaching_institute          Allen
# daily_study_hours             8.8
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 4979, dtype: object
#
#
#
# 4980
# jee_main_score               55.23
# jee_advanced_score           58.87
# mock_test_score_avg          53.67
# school_board                 State
# class_12_percent             88.74
# attempt_count                    1
# coaching_institute             NaN
# daily_study_hours              4.7
# family_income                  Mid
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 4980, dtype: object
#
#
#
# 4981
# jee_main_score              84.42
# jee_advanced_score          57.94
# mock_test_score_avg         64.17
# school_board                 CBSE
# class_12_percent            76.93
# attempt_count                   2
# coaching_institute          Allen
# daily_study_hours             4.8
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 4981, dtype: object
#
#
#
# 4982
# jee_main_score             76.01
# jee_advanced_score         74.41
# mock_test_score_avg        50.82
# school_board               State
# class_12_percent           80.28
# attempt_count                  2
# coaching_institute         Local
# daily_study_hours            2.9
# family_income               High
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level         High
# mental_health_issues         Yes
# admission_taken              Yes
# dropout                        0
# Name: 4982, dtype: object
#
#
#
# 4983
# jee_main_score               69.94
# jee_advanced_score            69.9
# mock_test_score_avg          100.0
# school_board                  CBSE
# class_12_percent             72.02
# attempt_count                    1
# coaching_institute           Local
# daily_study_hours              6.3
# family_income                  Mid
# parent_education          Graduate
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 4983, dtype: object
#
#
#
# 4984
# jee_main_score               79.91
# jee_advanced_score           46.91
# mock_test_score_avg          48.15
# school_board                 State
# class_12_percent             74.22
# attempt_count                    1
# coaching_institute           Allen
# daily_study_hours              3.4
# family_income                  Mid
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level            Low
# mental_health_issues            No
# admission_taken                 No
# dropout                          0
# Name: 4984, dtype: object
#
#
#
# 4985
# jee_main_score               94.9
# jee_advanced_score          59.72
# mock_test_score_avg         68.12
# school_board                State
# class_12_percent            74.51
# attempt_count                   2
# coaching_institute          Allen
# daily_study_hours             0.0
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level          High
# mental_health_issues          Yes
# admission_taken                No
# dropout                         1
# Name: 4985, dtype: object
#
#
#
# 4986
# jee_main_score             68.91
# jee_advanced_score         60.06
# mock_test_score_avg        81.72
# school_board                ICSE
# class_12_percent           77.93
# attempt_count                  1
# coaching_institute         Local
# daily_study_hours            3.4
# family_income                Mid
# parent_education        Graduate
# location_type              Rural
# peer_pressure_level          Low
# mental_health_issues          No
# admission_taken               No
# dropout                        0
# Name: 4986, dtype: object
#
#
#
# 4987
# jee_main_score              72.97
# jee_advanced_score          37.58
# mock_test_score_avg         80.44
# school_board                 CBSE
# class_12_percent            72.04
# attempt_count                   2
# coaching_institute        FIITJEE
# daily_study_hours             3.9
# family_income                 Mid
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level        Medium
# mental_health_issues           No
# admission_taken               Yes
# dropout                         0
# Name: 4987, dtype: object
#
#
#
# 4988
# jee_main_score             74.7
# jee_advanced_score         50.3
# mock_test_score_avg       78.22
# school_board               ICSE
# class_12_percent           88.4
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           4.2
# family_income               Low
# parent_education           12th
# location_type             Rural
# peer_pressure_level      Medium
# mental_health_issues         No
# admission_taken              No
# dropout                       1
# Name: 4988, dtype: object
#
#
#
# 4989
# jee_main_score               100.0
# jee_advanced_score           53.67
# mock_test_score_avg          64.19
# school_board                 State
# class_12_percent             71.27
# attempt_count                    2
# coaching_institute           Local
# daily_study_hours              4.1
# family_income                  Mid
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues            No
# admission_taken                 No
# dropout                          0
# Name: 4989, dtype: object
#
#
#
# 4990
# jee_main_score              42.61
# jee_advanced_score          88.94
# mock_test_score_avg         84.21
# school_board                 CBSE
# class_12_percent            57.93
# attempt_count                   2
# coaching_institute          Local
# daily_study_hours             3.2
# family_income                 Low
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level        Medium
# mental_health_issues           No
# admission_taken               Yes
# dropout                         0
# Name: 4990, dtype: object
#
#
#
# 4991
# jee_main_score               81.57
# jee_advanced_score           69.06
# mock_test_score_avg          78.96
# school_board                  ICSE
# class_12_percent             100.0
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              3.0
# family_income                 High
# parent_education         Upto 10th
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                 No
# dropout                          0
# Name: 4991, dtype: object
#
#
#
# 4992
# jee_main_score               70.39
# jee_advanced_score           76.59
# mock_test_score_avg          70.55
# school_board                 State
# class_12_percent             71.73
# attempt_count                    2
# coaching_institute           Allen
# daily_study_hours              3.9
# family_income                 High
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 4992, dtype: object
#
#
#
# 4993
# jee_main_score              79.93
# jee_advanced_score          42.02
# mock_test_score_avg         70.89
# school_board                 ICSE
# class_12_percent            88.13
# attempt_count                   1
# coaching_institute          Allen
# daily_study_hours             1.2
# family_income                High
# parent_education        Upto 10th
# location_type               Rural
# peer_pressure_level        Medium
# mental_health_issues           No
# admission_taken                No
# dropout                         0
# Name: 4993, dtype: object
#
#
#
# 4994
# jee_main_score                62.8
# jee_advanced_score           85.11
# mock_test_score_avg          64.35
# school_board                 State
# class_12_percent             89.05
# attempt_count                    1
# coaching_institute             NaN
# daily_study_hours              0.6
# family_income                 High
# parent_education              12th
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          1
# Name: 4994, dtype: object
#
#
#
# 4995
# jee_main_score               71.31
# jee_advanced_score           86.82
# mock_test_score_avg          57.08
# school_board                 State
# class_12_percent             84.45
# attempt_count                    1
# coaching_institute         FIITJEE
# daily_study_hours              4.7
# family_income                 High
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level           High
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 4995, dtype: object
#
#
#
# 4996
# jee_main_score          81.96
# jee_advanced_score      34.03
# mock_test_score_avg     82.85
# school_board             CBSE
# class_12_percent        73.02
# attempt_count               2
# coaching_institute      Local
# daily_study_hours         4.7
# family_income             Mid
# parent_education           PG
# location_type           Urban
# peer_pressure_level      High
# mental_health_issues      Yes
# admission_taken           Yes
# dropout                     0
# Name: 4996, dtype: object
#
#
#
# 4997
# jee_main_score               100.0
# jee_advanced_score           54.71
# mock_test_score_avg          83.75
# school_board                  CBSE
# class_12_percent             77.87
# attempt_count                    2
# coaching_institute             NaN
# daily_study_hours              6.3
# family_income                  Mid
# parent_education                PG
# location_type           Semi-Urban
# peer_pressure_level         Medium
# mental_health_issues           Yes
# admission_taken                Yes
# dropout                          0
# Name: 4997, dtype: object
#
#
#
# 4998
# jee_main_score              83.31
# jee_advanced_score          73.93
# mock_test_score_avg         57.39
# school_board                 CBSE
# class_12_percent            62.25
# attempt_count                   1
# coaching_institute          Allen
# daily_study_hours             4.0
# family_income                High
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken               Yes
# dropout                         0
# Name: 4998, dtype: object
#
#
#
# 4999
# jee_main_score            60.13
# jee_advanced_score        76.31
# mock_test_score_avg       66.15
# school_board              State
# class_12_percent           94.9
# attempt_count                 2
# coaching_institute      FIITJEE
# daily_study_hours           2.1
# family_income               Mid
# parent_education           12th
# location_type             Urban
# peer_pressure_level         Low
# mental_health_issues        Yes
# admission_taken              No
# dropout                       0
# Name: 4999, dtype: object

# %%
for index, row in jee.iterrows():
  print(index)
  print(row["jee_main_score"])
  print("\n\n")
# Out:
# 0
# 78.95
#
#
#
# 1
# 70.06
#
#
#
# 2
# 81.07
#
#
#
# 3
# 93.32
#
#
#
# 4
# 68.72
#
#
#
# 5
# 68.72
#
#
#
# 6
# 94.11
#
#
#
# 7
# 82.74
#
#
#
# 8
# 65.43
#
#
#
# 9
# 79.6
#
#
#
# 10
# 65.51
#
#
#
# 11
# 65.48
#
#
#
# 12
# 75.39
#
#
#
# 13
# 45.21
#
#
#
# 14
# 47.85
#
#
#
# 15
# 64.13
#
#
#
# 16
# 57.82
#
#
#
# 17
# 76.4
#
#
#
# 18
# 59.29
#
#
#
# 19
# 52.23
#
#
#
# 20
# 92.52
#
#
#
# 21
# 68.84
#
#
#
# 22
# 72.95
#
#
#
# 23
# 52.05
#
#
#
# 24
# 64.38
#
#
#
# 25
# 73.55
#
#
#
# 26
# 55.89
#
#
#
# 27
# 77.26
#
#
#
# 28
# 63.59
#
#
#
# 29
# 67.92
#
#
#
# 30
# 63.58
#
#
#
# 31
# 97.93
#
#
#
# 32
# 71.81
#
#
#
# 33
# 57.19
#
#
#
# 34
# 83.52
#
#
#
# 35
# 54.91
#
#
#
# 36
# 74.92
#
#
#
# 37
# 44.56
#
#
#
# 38
# 53.41
#
#
#
# 39
# 74.76
#
#
#
# 40
# 82.34
#
#
#
# 41
# 74.4
#
#
#
# 42
# 70.38
#
#
#
# 43
# 67.78
#
#
#
# 44
# 51.3
#
#
#
# 45
# 61.92
#
#
#
# 46
# 65.55
#
#
#
# 47
# 86.8
#
#
#
# 48
# 76.81
#
#
#
# 49
# 47.32
#
#
#
# 50
# 76.54
#
#
#
# 51
# 66.61
#
#
#
# 52
# 62.52
#
#
#
# 53
# 80.56
#
#
#
# 54
# 86.43
#
#
#
# 55
# 85.04
#
#
#
# 56
# 60.25
#
#
#
# 57
# 67.67
#
#
#
# 58
# 76.64
#
#
#
# 59
# 85.66
#
#
#
# 60
# 65.29
#
#
#
# 61
# 69.4
#
#
#
# 62
# 56.51
#
#
#
# 63
# 55.25
#
#
#
# 64
# 83.38
#
#
#
# 65
# 90.99
#
#
#
# 66
# 70.99
#
#
#
# 67
# 86.05
#
#
#
# 68
# 77.06
#
#
#
# 69
# 62.97
#
#
#
# 70
# 77.06
#
#
#
# 71
# 93.53
#
#
#
# 72
# 71.5
#
#
#
# 73
# 93.91
#
#
#
# 74
# 35.32
#
#
#
# 75
# 83.51
#
#
#
# 76
# 73.22
#
#
#
# 77
# 67.81
#
#
#
# 78
# 73.28
#
#
#
# 79
# 44.17
#
#
#
# 80
# 68.92
#
#
#
# 81
# 77.0
#
#
#
# 82
# 92.69
#
#
#
# 83
# 64.74
#
#
#
# 84
# 60.68
#
#
#
# 85
# 64.98
#
#
#
# 86
# 84.82
#
#
#
# 87
# 76.6
#
#
#
# 88
# 64.58
#
#
#
# 89
# 79.19
#
#
#
# 90
# 73.36
#
#
#
# 91
# 85.56
#
#
#
# 92
# 62.17
#
#
#
# 93
# 67.41
#
#
#
# 94
# 66.51
#
#
#
# 95
# 51.51
#
#
#
# 96
# 76.15
#
#
#
# 97
# 75.65
#
#
#
# 98
# 72.07
#
#
#
# 99
# 68.72
#
#
#
# 100
# 52.18
#
#
#
# 101
# 66.11
#
#
#
# 102
# 67.2
#
#
#
# 103
# 60.77
#
#
#
# 104
# 69.74
#
#
#
# 105
# 77.66
#
#
#
# 106
# 98.41
#
#
#
# 107
# 74.44
#
#
#
# 108
# 75.61
#
#
#
# 109
# 70.96
#
#
#
# 110
# 45.14
#
#
#
# 111
# 71.63
#
#
#
# 112
# 72.84
#
#
#
# 113
# 100.0
#
#
#
# 114
# 69.31
#
#
#
# 115
# 76.22
#
#
#
# 116
# 71.51
#
#
#
# 117
# 55.64
#
#
#
# 118
# 88.0
#
#
#
# 119
# 82.53
#
#
#
# 120
# 83.07
#
#
#
# 121
# 59.27
#
#
#
# 122
# 91.64
#
#
#
# 123
# 52.37
#
#
#
# 124
# 80.22
#
#
#
# 125
# 100.0
#
#
#
# 126
# 58.13
#
#
#
# 127
# 64.07
#
#
#
# 128
# 73.4
#
#
#
# 129
# 64.95
#
#
#
# 130
# 50.29
#
#
#
# 131
# 72.96
#
#
#
# 132
# 57.13
#
#
#
# 133
# 78.63
#
#
#
# 134
# 59.13
#
#
#
# 135
# 93.7
#
#
#
# 136
# 61.03
#
#
#
# 137
# 67.49
#
#
#
# 138
# 83.39
#
#
#
# 139
# 54.77
#
#
#
# 140
# 75.18
#
#
#
# 141
# 90.3
#
#
#
# 142
# 49.5
#
#
#
# 143
# 74.58
#
#
#
# 144
# 75.64
#
#
#
# 145
# 82.95
#
#
#
# 146
# 54.68
#
#
#
# 147
# 53.51
#
#
#
# 148
# 79.31
#
#
#
# 149
# 76.16
#
#
#
# 150
# 75.51
#
#
#
# 151
# 76.85
#
#
#
# 152
# 62.48
#
#
#
# 153
# 75.25
#
#
#
# 154
# 76.1
#
#
#
# 155
# 62.0
#
#
#
# 156
# 98.12
#
#
#
# 157
# 78.63
#
#
#
# 158
# 55.32
#
#
#
# 159
# 81.19
#
#
#
# 160
# 58.35
#
#
#
# 161
# 83.02
#
#
#
# 162
# 88.22
#
#
#
# 163
# 60.51
#
#
#
# 164
# 85.49
#
#
#
# 165
# 77.78
#
#
#
# 166
# 83.51
#
#
#
# 167
# 98.56
#
#
#
# 168
# 68.56
#
#
#
# 169
# 61.45
#
#
#
# 170
# 59.55
#
#
#
# 171
# 60.58
#
#
#
# 172
# 70.92
#
#
#
# 173
# 76.78
#
#
#
# 174
# 75.87
#
#
#
# 175
# 83.58
#
#
#
# 176
# 72.18
#
#
#
# 177
# 92.35
#
#
#
# 178
# 68.29
#
#
#
# 179
# 100.0
#
#
#
# 180
# 80.76
#
#
#
# 181
# 60.0
#
#
#
# 182
# 57.01
#
#
#
# 183
# 78.75
#
#
#
# 184
# 68.87
#
#
#
# 185
# 82.0
#
#
#
# 186
# 78.63
#
#
#
# 187
# 70.98
#
#
#
# 188
# 60.14
#
#
#
# 189
# 50.79
#
#
#
# 190
# 65.75
#
#
#
# 191
# 83.99
#
#
#
# 192
# 75.0
#
#
#
# 193
# 54.56
#
#
#
# 194
# 74.42
#
#
#
# 195
# 77.39
#
#
#
# 196
# 59.63
#
#
#
# 197
# 74.15
#
#
#
# 198
# 72.81
#
#
#
# 199
# 56.0
#
#
#
# 200
# 77.01
#
#
#
# 201
# 79.85
#
#
#
# 202
# 87.16
#
#
#
# 203
# 86.75
#
#
#
# 204
# 52.71
#
#
#
# 205
# 58.87
#
#
#
# 206
# 79.21
#
#
#
# 207
# 79.19
#
#
#
# 208
# 79.21
#
#
#
# 209
# 100.0
#
#
#
# 210
# 79.99
#
#
#
# 211
# 87.9
#
#
#
# 212
# 85.36
#
#
#
# 213
# 81.12
#
#
#
# 214
# 67.59
#
#
#
# 215
# 82.63
#
#
#
# 216
# 61.18
#
#
#
# 217
# 68.68
#
#
#
# 218
# 65.2
#
#
#
# 219
# 73.15
#
#
#
# 220
# 100.0
#
#
#
# 221
# 45.86
#
#
#
# 222
# 81.61
#
#
#
# 223
# 49.42
#
#
#
# 224
# 65.39
#
#
#
# 225
# 87.25
#
#
#
# 226
# 72.9
#
#
#
# 227
# 56.91
#
#
#
# 228
# 61.99
#
#
#
# 229
# 81.51
#
#
#
# 230
# 61.77
#
#
#
# 231
# 75.03
#
#
#
# 232
# 72.64
#
#
#
# 233
# 62.88
#
#
#
# 234
# 100.0
#
#
#
# 235
# 80.87
#
#
#
# 236
# 43.65
#
#
#
# 237
# 74.61
#
#
#
# 238
# 62.73
#
#
#
# 239
# 83.93
#
#
#
# 240
# 60.9
#
#
#
# 241
# 70.39
#
#
#
# 242
# 79.07
#
#
#
# 243
# 84.12
#
#
#
# 244
# 55.2
#
#
#
# 245
# 67.32
#
#
#
# 246
# 65.35
#
#
#
# 247
# 62.85
#
#
#
# 248
# 96.72
#
#
#
# 249
# 77.67
#
#
#
# 250
# 54.35
#
#
#
# 251
# 84.85
#
#
#
# 252
# 100.0
#
#
#
# 253
# 86.45
#
#
#
# 254
# 50.73
#
#
#
# 255
# 65.22
#
#
#
# 256
# 89.74
#
#
#
# 257
# 62.09
#
#
#
# 258
# 78.21
#
#
#
# 259
# 82.84
#
#
#
# 260
# 59.02
#
#
#
# 261
# 71.17
#
#
#
# 262
# 26.62
#
#
#
# 263
# 57.66
#
#
#
# 264
# 68.46
#
#
#
# 265
# 54.53
#
#
#
# 266
# 94.85
#
#
#
# 267
# 51.98
#
#
#
# 268
# 65.84
#
#
#
# 269
# 73.83
#
#
#
# 270
# 92.18
#
#
#
# 271
# 51.9
#
#
#
# 272
# 88.28
#
#
#
# 273
# 72.14
#
#
#
# 274
# 58.26
#
#
#
# 275
# 78.47
#
#
#
# 276
# 74.79
#
#
#
# 277
# 63.6
#
#
#
# 278
# 72.98
#
#
#
# 279
# 66.61
#
#
#
# 280
# 73.59
#
#
#
# 281
# 81.27
#
#
#
# 282
# 94.2
#
#
#
# 283
# 54.67
#
#
#
# 284
# 100.0
#
#
#
# 285
# 44.67
#
#
#
# 286
# 69.88
#
#
#
# 287
# 80.24
#
#
#
# 288
# 75.93
#
#
#
# 289
# 63.28
#
#
#
# 290
# 69.09
#
#
#
# 291
# 65.1
#
#
#
# 292
# 63.75
#
#
#
# 293
# 83.89
#
#
#
# 294
# 77.0
#
#
#
# 295
# 62.3
#
#
#
# 296
# 84.59
#
#
#
# 297
# 76.3
#
#
#
# 298
# 83.38
#
#
#
# 299
# 80.81
#
#
#
# 300
# 60.39
#
#
#
# 301
# 64.16
#
#
#
# 302
# 82.46
#
#
#
# 303
# 80.55
#
#
#
# 304
# 71.71
#
#
#
# 305
# 73.64
#
#
#
# 306
# 89.89
#
#
#
# 307
# 63.72
#
#
#
# 308
# 79.66
#
#
#
# 309
# 69.17
#
#
#
# 310
# 68.95
#
#
#
# 311
# 87.38
#
#
#
# 312
# 83.56
#
#
#
# 313
# 83.39
#
#
#
# 314
# 90.28
#
#
#
# 315
# 72.29
#
#
#
# 316
# 81.55
#
#
#
# 317
# 67.66
#
#
#
# 318
# 76.54
#
#
#
# 319
# 70.18
#
#
#
# 320
# 73.36
#
#
#
# 321
# 80.33
#
#
#
# 322
# 60.54
#
#
#
# 323
# 100.0
#
#
#
# 324
# 57.92
#
#
#
# 325
# 55.0
#
#
#
# 326
# 88.21
#
#
#
# 327
# 83.08
#
#
#
# 328
# 80.74
#
#
#
# 329
# 80.8
#
#
#
# 330
# 71.83
#
#
#
# 331
# 59.44
#
#
#
# 332
# 73.06
#
#
#
# 333
# 62.52
#
#
#
# 334
# 85.65
#
#
#
# 335
# 69.94
#
#
#
# 336
# 60.44
#
#
#
# 337
# 67.5
#
#
#
# 338
# 77.78
#
#
#
# 339
# 64.11
#
#
#
# 340
# 60.49
#
#
#
# 341
# 75.41
#
#
#
# 342
# 75.43
#
#
#
# 343
# 64.9
#
#
#
# 344
# 65.41
#
#
#
# 345
# 75.25
#
#
#
# 346
# 51.73
#
#
#
# 347
# 52.3
#
#
#
# 348
# 61.94
#
#
#
# 349
# 69.01
#
#
#
# 350
# 76.35
#
#
#
# 351
# 92.65
#
#
#
# 352
# 84.01
#
#
#
# 353
# 69.76
#
#
#
# 354
# 71.73
#
#
#
# 355
# 57.96
#
#
#
# 356
# 71.74
#
#
#
# 357
# 67.96
#
#
#
# 358
# 76.52
#
#
#
# 359
# 60.42
#
#
#
# 360
# 79.27
#
#
#
# 361
# 93.46
#
#
#
# 362
# 70.48
#
#
#
# 363
# 77.62
#
#
#
# 364
# 81.66
#
#
#
# 365
# 66.38
#
#
#
# 366
# 75.14
#
#
#
# 367
# 72.18
#
#
#
# 368
# 73.37
#
#
#
# 369
# 61.18
#
#
#
# 370
# 72.34
#
#
#
# 371
# 78.97
#
#
#
# 372
# 92.32
#
#
#
# 373
# 85.43
#
#
#
# 374
# 100.0
#
#
#
# 375
# 61.26
#
#
#
# 376
# 84.21
#
#
#
# 377
# 74.57
#
#
#
# 378
# 100.0
#
#
#
# 379
# 60.68
#
#
#
# 380
# 60.24
#
#
#
# 381
# 63.61
#
#
#
# 382
# 42.27
#
#
#
# 383
# 64.64
#
#
#
# 384
# 61.37
#
#
#
# 385
# 74.11
#
#
#
# 386
# 76.78
#
#
#
# 387
# 98.27
#
#
#
# 388
# 85.31
#
#
#
# 389
# 63.92
#
#
#
# 390
# 59.42
#
#
#
# 391
# 78.89
#
#
#
# 392
# 53.52
#
#
#
# 393
# 97.64
#
#
#
# 394
# 88.51
#
#
#
# 395
# 65.43
#
#
#
# 396
# 48.02
#
#
#
# 397
# 90.95
#
#
#
# 398
# 70.4
#
#
#
# 399
# 89.33
#
#
#
# 400
# 49.68
#
#
#
# 401
# 63.61
#
#
#
# 402
# 72.07
#
#
#
# 403
# 72.66
#
#
#
# 404
# 65.7
#
#
#
# 405
# 80.72
#
#
#
# 406
# 57.05
#
#
#
# 407
# 70.01
#
#
#
# 408
# 73.68
#
#
#
# 409
# 79.2
#
#
#
# 410
# 81.96
#
#
#
# 411
# 56.26
#
#
#
# 412
# 50.52
#
#
#
# 413
# 89.89
#
#
#
# 414
# 76.65
#
#
#
# 415
# 61.52
#
#
#
# 416
# 93.72
#
#
#
# 417
# 73.62
#
#
#
# 418
# 88.51
#
#
#
# 419
# 72.95
#
#
#
# 420
# 100.0
#
#
#
# 421
# 96.57
#
#
#
# 422
# 68.51
#
#
#
# 423
# 85.6
#
#
#
# 424
# 81.04
#
#
#
# 425
# 91.16
#
#
#
# 426
# 58.49
#
#
#
# 427
# 81.6
#
#
#
# 428
# 86.82
#
#
#
# 429
# 47.38
#
#
#
# 430
# 55.43
#
#
#
# 431
# 43.45
#
#
#
# 432
# 68.23
#
#
#
# 433
# 82.05
#
#
#
# 434
# 93.03
#
#
#
# 435
# 73.04
#
#
#
# 436
# 94.8
#
#
#
# 437
# 52.68
#
#
#
# 438
# 48.15
#
#
#
# 439
# 71.22
#
#
#
# 440
# 77.38
#
#
#
# 441
# 71.54
#
#
#
# 442
# 43.06
#
#
#
# 443
# 70.75
#
#
#
# 444
# 53.74
#
#
#
# 445
# 81.38
#
#
#
# 446
# 77.13
#
#
#
# 447
# 58.84
#
#
#
# 448
# 64.81
#
#
#
# 449
# 57.17
#
#
#
# 450
# 71.12
#
#
#
# 451
# 85.37
#
#
#
# 452
# 58.2
#
#
#
# 453
# 79.06
#
#
#
# 454
# 64.58
#
#
#
# 455
# 60.9
#
#
#
# 456
# 70.5
#
#
#
# 457
# 57.51
#
#
#
# 458
# 64.25
#
#
#
# 459
# 55.23
#
#
#
# 460
# 99.51
#
#
#
# 461
# 72.49
#
#
#
# 462
# 62.2
#
#
#
# 463
# 75.0
#
#
#
# 464
# 70.43
#
#
#
# 465
# 68.91
#
#
#
# 466
# 80.6
#
#
#
# 467
# 82.61
#
#
#
# 468
# 64.57
#
#
#
# 469
# 63.94
#
#
#
# 470
# 68.15
#
#
#
# 471
# 39.77
#
#
#
# 472
# 50.79
#
#
#
# 473
# 91.14
#
#
#
# 474
# 95.03
#
#
#
# 475
# 68.51
#
#
#
# 476
# 80.07
#
#
#
# 477
# 76.36
#
#
#
# 478
# 100.0
#
#
#
# 479
# 87.67
#
#
#
# 480
# 70.21
#
#
#
# 481
# 58.62
#
#
#
# 482
# 49.51
#
#
#
# 483
# 74.85
#
#
#
# 484
# 61.41
#
#
#
# 485
# 52.09
#
#
#
# 486
# 62.95
#
#
#
# 487
# 56.86
#
#
#
# 488
# 95.62
#
#
#
# 489
# 84.34
#
#
#
# 490
# 71.89
#
#
#
# 491
# 92.72
#
#
#
# 492
# 73.08
#
#
#
# 493
# 59.94
#
#
#
# 494
# 93.32
#
#
#
# 495
# 79.54
#
#
#
# 496
# 57.48
#
#
#
# 497
# 69.34
#
#
#
# 498
# 59.74
#
#
#
# 499
# 52.64
#
#
#
# 500
# 84.97
#
#
#
# 501
# 98.73
#
#
#
# 502
# 52.42
#
#
#
# 503
# 79.88
#
#
#
# 504
# 62.89
#
#
#
# 505
# 65.18
#
#
#
# 506
# 63.71
#
#
#
# 507
# 59.9
#
#
#
# 508
# 72.68
#
#
#
# 509
# 60.37
#
#
#
# 510
# 75.79
#
#
#
# 511
# 71.3
#
#
#
# 512
# 68.65
#
#
#
# 513
# 59.29
#
#
#
# 514
# 63.93
#
#
#
# 515
# 82.58
#
#
#
# 516
# 79.01
#
#
#
# 517
# 58.31
#
#
#
# 518
# 73.39
#
#
#
# 519
# 82.52
#
#
#
# 520
# 48.63
#
#
#
# 521
# 79.61
#
#
#
# 522
# 62.72
#
#
#
# 523
# 79.99
#
#
#
# 524
# 61.31
#
#
#
# 525
# 46.73
#
#
#
# 526
# 49.21
#
#
#
# 527
# 72.67
#
#
#
# 528
# 75.64
#
#
#
# 529
# 59.34
#
#
#
# 530
# 80.94
#
#
#
# 531
# 48.74
#
#
#
# 532
# 71.07
#
#
#
# 533
# 55.05
#
#
#
# 534
# 62.87
#
#
#
# 535
# 72.66
#
#
#
# 536
# 59.95
#
#
#
# 537
# 66.62
#
#
#
# 538
# 86.09
#
#
#
# 539
# 63.92
#
#
#
# 540
# 83.7
#
#
#
# 541
# 56.18
#
#
#
# 542
# 79.42
#
#
#
# 543
# 92.18
#
#
#
# 544
# 37.4
#
#
#
# 545
# 60.84
#
#
#
# 546
# 80.08
#
#
#
# 547
# 69.16
#
#
#
# 548
# 77.2
#
#
#
# 549
# 63.54
#
#
#
# 550
# 73.21
#
#
#
# 551
# 69.82
#
#
#
# 552
# 88.35
#
#
#
# 553
# 75.56
#
#
#
# 554
# 76.73
#
#
#
# 555
# 66.23
#
#
#
# 556
# 65.17
#
#
#
# 557
# 65.94
#
#
#
# 558
# 77.52
#
#
#
# 559
# 66.11
#
#
#
# 560
# 76.06
#
#
#
# 561
# 100.0
#
#
#
# 562
# 84.2
#
#
#
# 563
# 67.44
#
#
#
# 564
# 88.82
#
#
#
# 565
# 66.29
#
#
#
# 566
# 43.47
#
#
#
# 567
# 57.89
#
#
#
# 568
# 45.81
#
#
#
# 569
# 67.08
#
#
#
# 570
# 72.26
#
#
#
# 571
# 95.47
#
#
#
# 572
# 76.58
#
#
#
# 573
# 68.93
#
#
#
# 574
# 83.61
#
#
#
# 575
# 41.04
#
#
#
# 576
# 75.3
#
#
#
# 577
# 82.79
#
#
#
# 578
# 51.3
#
#
#
# 579
# 88.01
#
#
#
# 580
# 76.74
#
#
#
# 581
# 66.19
#
#
#
# 582
# 80.86
#
#
#
# 583
# 100.0
#
#
#
# 584
# 74.55
#
#
#
# 585
# 75.48
#
#
#
# 586
# 65.57
#
#
#
# 587
# 60.1
#
#
#
# 588
# 83.62
#
#
#
# 589
# 60.01
#
#
#
# 590
# 73.0
#
#
#
# 591
# 65.31
#
#
#
# 592
# 78.71
#
#
#
# 593
# 76.67
#
#
#
# 594
# 86.53
#
#
#
# 595
# 64.86
#
#
#
# 596
# 68.22
#
#
#
# 597
# 58.3
#
#
#
# 598
# 65.78
#
#
#
# 599
# 77.28
#
#
#
# 600
# 82.6
#
#
#
# 601
# 59.09
#
#
#
# 602
# 84.17
#
#
#
# 603
# 90.98
#
#
#
# 604
# 77.79
#
#
#
# 605
# 98.28
#
#
#
# 606
# 61.17
#
#
#
# 607
# 54.57
#
#
#
# 608
# 47.1
#
#
#
# 609
# 92.94
#
#
#
# 610
# 81.16
#
#
#
# 611
# 71.22
#
#
#
# 612
# 75.92
#
#
#
# 613
# 56.24
#
#
#
# 614
# 100.0
#
#
#
# 615
# 73.81
#
#
#
# 616
# 73.53
#
#
#
# 617
# 82.16
#
#
#
# 618
# 78.73
#
#
#
# 619
# 75.13
#
#
#
# 620
# 60.93
#
#
#
# 621
# 78.6
#
#
#
# 622
# 98.35
#
#
#
# 623
# 90.84
#
#
#
# 624
# 94.3
#
#
#
# 625
# 64.84
#
#
#
# 626
# 58.15
#
#
#
# 627
# 70.24
#
#
#
# 628
# 72.78
#
#
#
# 629
# 87.32
#
#
#
# 630
# 48.31
#
#
#
# 631
# 93.41
#
#
#
# 632
# 69.79
#
#
#
# 633
# 66.02
#
#
#
# 634
# 57.83
#
#
#
# 635
# 48.83
#
#
#
# 636
# 83.52
#
#
#
# 637
# 73.03
#
#
#
# 638
# 53.94
#
#
#
# 639
# 53.87
#
#
#
# 640
# 67.3
#
#
#
# 641
# 95.37
#
#
#
# 642
# 68.37
#
#
#
# 643
# 50.96
#
#
#
# 644
# 68.56
#
#
#
# 645
# 68.18
#
#
#
# 646
# 34.24
#
#
#
# 647
# 71.24
#
#
#
# 648
# 68.77
#
#
#
# 649
# 81.75
#
#
#
# 650
# 97.89
#
#
#
# 651
# 87.77
#
#
#
# 652
# 68.24
#
#
#
# 653
# 56.51
#
#
#
# 654
# 100.0
#
#
#
# 655
# 72.83
#
#
#
# 656
# 72.2
#
#
#
# 657
# 71.66
#
#
#
# 658
# 74.77
#
#
#
# 659
# 69.98
#
#
#
# 660
# 63.97
#
#
#
# 661
# 64.34
#
#
#
# 662
# 71.54
#
#
#
# 663
# 64.39
#
#
#
# 664
# 62.02
#
#
#
# 665
# 73.49
#
#
#
# 666
# 68.43
#
#
#
# 667
# 93.06
#
#
#
# 668
# 34.89
#
#
#
# 669
# 87.28
#
#
#
# 670
# 89.45
#
#
#
# 671
# 42.97
#
#
#
# 672
# 67.2
#
#
#
# 673
# 66.8
#
#
#
# 674
# 52.29
#
#
#
# 675
# 61.11
#
#
#
# 676
# 56.45
#
#
#
# 677
# 96.53
#
#
#
# 678
# 85.1
#
#
#
# 679
# 89.8
#
#
#
# 680
# 82.1
#
#
#
# 681
# 56.19
#
#
#
# 682
# 64.66
#
#
#
# 683
# 78.85
#
#
#
# 684
# 54.89
#
#
#
# 685
# 81.98
#
#
#
# 686
# 68.64
#
#
#
# 687
# 66.75
#
#
#
# 688
# 81.95
#
#
#
# 689
# 78.22
#
#
#
# 690
# 66.95
#
#
#
# 691
# 88.23
#
#
#
# 692
# 56.87
#
#
#
# 693
# 80.62
#
#
#
# 694
# 80.3
#
#
#
# 695
# 67.67
#
#
#
# 696
# 76.57
#
#
#
# 697
# 54.48
#
#
#
# 698
# 84.94
#
#
#
# 699
# 69.41
#
#
#
# 700
# 64.68
#
#
#
# 701
# 86.69
#
#
#
# 702
# 62.14
#
#
#
# 703
# 52.28
#
#
#
# 704
# 50.21
#
#
#
# 705
# 80.48
#
#
#
# 706
# 54.07
#
#
#
# 707
# 96.57
#
#
#
# 708
# 42.85
#
#
#
# 709
# 95.75
#
#
#
# 710
# 74.95
#
#
#
# 711
# 70.65
#
#
#
# 712
# 64.37
#
#
#
# 713
# 77.59
#
#
#
# 714
# 71.47
#
#
#
# 715
# 87.45
#
#
#
# 716
# 73.6
#
#
#
# 717
# 74.1
#
#
#
# 718
# 66.91
#
#
#
# 719
# 71.2
#
#
#
# 720
# 76.31
#
#
#
# 721
# 48.06
#
#
#
# 722
# 53.13
#
#
#
# 723
# 82.41
#
#
#
# 724
# 74.39
#
#
#
# 725
# 69.42
#
#
#
# 726
# 72.26
#
#
#
# 727
# 76.87
#
#
#
# 728
# 64.44
#
#
#
# 729
# 61.1
#
#
#
# 730
# 74.74
#
#
#
# 731
# 58.3
#
#
#
# 732
# 77.72
#
#
#
# 733
# 48.16
#
#
#
# 734
# 86.41
#
#
#
# 735
# 78.62
#
#
#
# 736
# 75.58
#
#
#
# 737
# 85.76
#
#
#
# 738
# 95.32
#
#
#
# 739
# 86.2
#
#
#
# 740
# 46.23
#
#
#
# 741
# 54.09
#
#
#
# 742
# 63.25
#
#
#
# 743
# 72.37
#
#
#
# 744
# 79.25
#
#
#
# 745
# 61.84
#
#
#
# 746
# 74.61
#
#
#
# 747
# 61.42
#
#
#
# 748
# 63.44
#
#
#
# 749
# 52.31
#
#
#
# 750
# 59.07
#
#
#
# 751
# 53.08
#
#
#
# 752
# 58.34
#
#
#
# 753
# 86.75
#
#
#
# 754
# 58.71
#
#
#
# 755
# 100.0
#
#
#
# 756
# 78.91
#
#
#
# 757
# 74.59
#
#
#
# 758
# 59.98
#
#
#
# 759
# 81.8
#
#
#
# 760
# 63.94
#
#
#
# 761
# 73.71
#
#
#
# 762
# 100.0
#
#
#
# 763
# 70.66
#
#
#
# 764
# 88.09
#
#
#
# 765
# 62.16
#
#
#
# 766
# 71.51
#
#
#
# 767
# 96.79
#
#
#
# 768
# 63.22
#
#
#
# 769
# 97.37
#
#
#
# 770
# 81.91
#
#
#
# 771
# 64.13
#
#
#
# 772
# 80.85
#
#
#
# 773
# 85.62
#
#
#
# 774
# 80.71
#
#
#
# 775
# 50.02
#
#
#
# 776
# 61.82
#
#
#
# 777
# 68.53
#
#
#
# 778
# 70.96
#
#
#
# 779
# 80.69
#
#
#
# 780
# 74.49
#
#
#
# 781
# 53.31
#
#
#
# 782
# 77.32
#
#
#
# 783
# 80.55
#
#
#
# 784
# 79.84
#
#
#
# 785
# 87.13
#
#
#
# 786
# 83.67
#
#
#
# 787
# 78.43
#
#
#
# 788
# 71.02
#
#
#
# 789
# 48.75
#
#
#
# 790
# 78.01
#
#
#
# 791
# 74.91
#
#
#
# 792
# 75.8
#
#
#
# 793
# 54.13
#
#
#
# 794
# 56.87
#
#
#
# 795
# 86.74
#
#
#
# 796
# 71.45
#
#
#
# 797
# 81.54
#
#
#
# 798
# 72.4
#
#
#
# 799
# 72.42
#
#
#
# 800
# 85.14
#
#
#
# 801
# 64.78
#
#
#
# 802
# 73.35
#
#
#
# 803
# 65.53
#
#
#
# 804
# 65.92
#
#
#
# 805
# 67.67
#
#
#
# 806
# 75.11
#
#
#
# 807
# 65.3
#
#
#
# 808
# 89.58
#
#
#
# 809
# 59.48
#
#
#
# 810
# 69.38
#
#
#
# 811
# 65.84
#
#
#
# 812
# 92.26
#
#
#
# 813
# 74.75
#
#
#
# 814
# 86.45
#
#
#
# 815
# 51.2
#
#
#
# 816
# 75.74
#
#
#
# 817
# 84.45
#
#
#
# 818
# 73.15
#
#
#
# 819
# 86.92
#
#
#
# 820
# 64.76
#
#
#
# 821
# 91.73
#
#
#
# 822
# 100.0
#
#
#
# 823
# 66.92
#
#
#
# 824
# 65.76
#
#
#
# 825
# 92.35
#
#
#
# 826
# 94.11
#
#
#
# 827
# 64.68
#
#
#
# 828
# 66.12
#
#
#
# 829
# 68.06
#
#
#
# 830
# 53.18
#
#
#
# 831
# 59.14
#
#
#
# 832
# 57.94
#
#
#
# 833
# 61.25
#
#
#
# 834
# 71.51
#
#
#
# 835
# 75.28
#
#
#
# 836
# 93.71
#
#
#
# 837
# 58.02
#
#
#
# 838
# 85.78
#
#
#
# 839
# 69.0
#
#
#
# 840
# 71.31
#
#
#
# 841
# 81.45
#
#
#
# 842
# 56.28
#
#
#
# 843
# 77.35
#
#
#
# 844
# 74.33
#
#
#
# 845
# 78.89
#
#
#
# 846
# 76.05
#
#
#
# 847
# 100.0
#
#
#
# 848
# 63.07
#
#
#
# 849
# 64.57
#
#
#
# 850
# 63.28
#
#
#
# 851
# 64.22
#
#
#
# 852
# 63.08
#
#
#
# 853
# 88.65
#
#
#
# 854
# 91.89
#
#
#
# 855
# 64.01
#
#
#
# 856
# 60.35
#
#
#
# 857
# 78.6
#
#
#
# 858
# 64.27
#
#
#
# 859
# 80.86
#
#
#
# 860
# 74.84
#
#
#
# 861
# 50.78
#
#
#
# 862
# 93.67
#
#
#
# 863
# 97.14
#
#
#
# 864
# 63.42
#
#
#
# 865
# 66.57
#
#
#
# 866
# 76.0
#
#
#
# 867
# 76.68
#
#
#
# 868
# 81.22
#
#
#
# 869
# 100.0
#
#
#
# 870
# 69.52
#
#
#
# 871
# 60.82
#
#
#
# 872
# 52.69
#
#
#
# 873
# 61.77
#
#
#
# 874
# 71.54
#
#
#
# 875
# 97.12
#
#
#
# 876
# 64.75
#
#
#
# 877
# 75.13
#
#
#
# 878
# 71.77
#
#
#
# 879
# 88.64
#
#
#
# 880
# 100.0
#
#
#
# 881
# 64.57
#
#
#
# 882
# 65.15
#
#
#
# 883
# 86.62
#
#
#
# 884
# 81.55
#
#
#
# 885
# 97.85
#
#
#
# 886
# 80.17
#
#
#
# 887
# 66.97
#
#
#
# 888
# 80.27
#
#
#
# 889
# 87.52
#
#
#
# 890
# 83.49
#
#
#
# 891
# 79.1
#
#
#
# 892
# 86.93
#
#
#
# 893
# 88.37
#
#
#
# 894
# 91.35
#
#
#
# 895
# 81.08
#
#
#
# 896
# 69.66
#
#
#
# 897
# 74.05
#
#
#
# 898
# 88.89
#
#
#
# 899
# 60.56
#
#
#
# 900
# 77.16
#
#
#
# 901
# 66.49
#
#
#
# 902
# 72.4
#
#
#
# 903
# 89.9
#
#
#
# 904
# 74.68
#
#
#
# 905
# 72.65
#
#
#
# 906
# 52.96
#
#
#
# 907
# 82.45
#
#
#
# 908
# 81.04
#
#
#
# 909
# 100.0
#
#
#
# 910
# 67.69
#
#
#
# 911
# 75.07
#
#
#
# 912
# 75.49
#
#
#
# 913
# 94.08
#
#
#
# 914
# 70.67
#
#
#
# 915
# 75.91
#
#
#
# 916
# 80.51
#
#
#
# 917
# 74.61
#
#
#
# 918
# 65.75
#
#
#
# 919
# 74.72
#
#
#
# 920
# 87.03
#
#
#
# 921
# 57.63
#
#
#
# 922
# 73.86
#
#
#
# 923
# 62.2
#
#
#
# 924
# 88.73
#
#
#
# 925
# 50.68
#
#
#
# 926
# 64.18
#
#
#
# 927
# 77.28
#
#
#
# 928
# 93.92
#
#
#
# 929
# 71.08
#
#
#
# 930
# 64.23
#
#
#
# 931
# 98.34
#
#
#
# 932
# 51.73
#
#
#
# 933
# 41.22
#
#
#
# 934
# 78.16
#
#
#
# 935
# 64.97
#
#
#
# 936
# 57.7
#
#
#
# 937
# 81.92
#
#
#
# 938
# 75.41
#
#
#
# 939
# 64.1
#
#
#
# 940
# 54.08
#
#
#
# 941
# 84.21
#
#
#
# 942
# 81.1
#
#
#
# 943
# 70.61
#
#
#
# 944
# 97.85
#
#
#
# 945
# 57.02
#
#
#
# 946
# 50.64
#
#
#
# 947
# 62.31
#
#
#
# 948
# 71.36
#
#
#
# 949
# 75.41
#
#
#
# 950
# 68.62
#
#
#
# 951
# 76.93
#
#
#
# 952
# 54.48
#
#
#
# 953
# 92.21
#
#
#
# 954
# 70.85
#
#
#
# 955
# 87.64
#
# 2503
# 63.43
#
#
#
# 2504
# 56.81
#
#
#
# 2505
# 60.44
#
#
#
# 2506
# 100.0
#
#
#
# 2507
# 89.43
#
#
#
# 2508
# 53.08
#
#
#
# 2509
# 53.49
#
#
#
# 2510
# 78.75
#
#
#
# 2511
# 79.66
#
#
#
# 2512
# 79.68
#
#
#
# 2513
# 68.43
#
#
#
# 2514
# 70.24
#
#
#
# 2515
# 76.59
#
#
#
# 2516
# 73.2
#
#
#
# 2517
# 40.93
#
#
#
# 2518
# 68.78
#
#
#
# 2519
# 60.08
#
#
#
# 2520
# 74.45
#
#
#
# 2521
# 100.0
#
#
#
# 2522
# 77.14
#
#
#
# 2523
# 67.61
#
#
#
# 2524
# 84.91
#
#
#
# 2525
# 78.76
#
#
#
# 2526
# 77.88
#
#
#
# 2527
# 80.5
#
#
#
# 2528
# 100.0
#
#
#
# 2529
# 56.17
#
#
#
# 2530
# 78.63
#
#
#
# 2531
# 59.03
#
#
#
# 2532
# 79.78
#
#
#
# 2533
# 59.14
#
#
#
# 2534
# 66.16
#
#
#
# 2535
# 67.87
#
#
#
# 2536
# 85.66
#
#
#
# 2537
# 84.86
#
#
#
# 2538
# 54.56
#
#
#
# 2539
# 72.77
#
#
#
# 2540
# 62.07
#
#
#
# 2541
# 54.38
#
#
#
# 2542
# 68.96
#
#
#
# 2543
# 67.68
#
#
#
# 2544
# 100.0
#
#
#
# 2545
# 78.06
#
#
#
# 2546
# 52.71
#
#
#
# 2547
# 64.09
#
#
#
# 2548
# 86.3
#
#
#
# 2549
# 100.0
#
#
#
# 2550
# 49.8
#
#
#
# 2551
# 45.68
#
#
#
# 2552
# 98.19
#
#
#
# 2553
# 77.45
#
#
#
# 2554
# 59.84
#
#
#
# 2555
# 79.48
#
#
#
# 2556
# 35.1
#
#
#
# 2557
# 72.05
#
#
#
# 2558
# 76.59
#
#
#
# 2559
# 84.94
#
#
#
# 2560
# 57.81
#
#
#
# 2561
# 73.2
#
#
#
# 2562
# 59.04
#
#
#
# 2563
# 75.58
#
#
#
# 2564
# 59.47
#
#
#
# 2565
# 66.29
#
#
#
# 2566
# 58.06
#
#
#
# 2567
# 81.12
#
#
#
# 2568
# 84.02
#
#
#
# 2569
# 68.72
#
#
#
# 2570
# 72.54
#
#
#
# 2571
# 51.72
#
#
#
# 2572
# 67.8
#
#
#
# 2573
# 71.3
#
#
#
# 2574
# 100.0
#
#
#
# 2575
# 56.43
#
#
#
# 2576
# 92.5
#
#
#
# 2577
# 85.96
#
#
#
# 2578
# 75.93
#
#
#
# 2579
# 96.62
#
#
#
# 2580
# 77.21
#
#
#
# 2581
# 77.45
#
#
#
# 2582
# 71.26
#
#
#
# 2583
# 89.13
#
#
#
# 2584
# 87.35
#
#
#
# 2585
# 63.24
#
#
#
# 2586
# 53.53
#
#
#
# 2587
# 69.16
#
#
#
# 2588
# 60.8
#
#
#
# 2589
# 71.11
#
#
#
# 2590
# 89.32
#
#
#
# 2591
# 65.6
#
#
#
# 2592
# 71.4
#
#
#
# 2593
# 72.81
#
#
# 68.69
#
#
#
# 2958
# 87.9
#
#
#
# 2959
# 56.51
#
#
#
# 2960
# 60.46
#
#
#
# 2961
# 63.48
#
#
#
# 2962
# 64.59
#
#
#
# 2963
# 57.21
#
#
#
# 2964
# 89.12
#
#
#
# 2965
# 68.38
#
#
#
# 2966
# 76.94
#
#
#
# 2967
# 64.02
#
#
#
# 2968
# 46.51
#
#
#
# 2969
# 75.78
#
#
#
# 2970
# 45.23
#
#
#
# 2971
# 71.04
#
#
#
# 2972
# 52.84
#
#
#
# 2973
# 99.82
#
#
#
# 2974
# 84.76
#
#
#
# 2975
# 73.48
#
#
#
# 2976
# 89.69
#
#
#
# 2977
# 60.15
#
#
#
# 2978
# 79.61
#
#
#
# 2979
# 74.8
#
#
#
# 2980
# 75.7
#
#
#
# 2981
# 89.81
#
#
#
# 2982
# 82.25
#
#
#
# 2983
# 76.04
#
#
#
# 2984
# 48.83
#
#
#
# 2985
# 58.56
#
#
#
# 2986
# 70.28
#
#
#
# 2987
# 73.31
#
#
#
# 2988
# 56.18
#
#
#
# 2989
# 100.0
#
#
#
# 2990
# 93.23
#
#
#
# 2991
# 80.43
#
#
#
# 2992
# 73.01
#
#
#
# 2993
# 69.03
#
#
#
# 2994
# 58.67
#
#
#
# 2995
# 73.08
#
#
#
# 2996
# 75.61
#
#
#
# 2997
# 54.62
#
#
#
# 2998
# 76.68
#
#
#
# 2999
# 69.83
#
#
#
# 3000
# 45.29
#
#
#
# 3001
# 59.95
#
#
#
# 3002
# 66.21
#
#
#
# 3003
# 98.43
#
#
#
# 3004
# 79.79
#
#
#
# 3005
# 53.3
#
#
#
# 3006
# 78.8
#
#
#
# 3007
# 50.34
#
#
#
# 3008
# 87.16
#
#
#
# 3009
# 65.4
#
#
#
# 3010
# 70.69
#
#
#
# 3011
# 90.56
#
#
#
# 3012
# 53.98
#
#
#
# 3013
# 52.44
#
#
#
# 3014
# 63.83
#
#
#
# 3015
# 86.54
#
#
#
# 3016
# 50.73
#
#
#
# 3017
# 32.35
#
#
#
# 3018
# 65.68
#
#
#
# 3019
# 79.72
#
#
#
# 3020
# 88.8
#
#
#
# 3021
# 65.52
#
#
#
# 3022
# 66.24
#
#
#
# 3023
# 88.15
#
#
#
# 3024
# 45.82
#
#
#
# 3025
# 66.56
#
#
#
# 3026
# 74.67
#
#
#
# 3027
# 78.29
#
#
#
# 3028
# 64.86
#
#
#
# 3029
# 72.48
#
#
#
# 3030
# 37.16
#
#
#
# 3031
# 62.78
#
#
#
# 3032
# 78.35
#
#
#
# 3033
# 58.25
#
#
#
# 3034
# 72.83
#
#
#
# 3035
# 78.26
#
#
#
# 3036
# 67.2
#
#
#
# 3037
# 74.39
#
#
#
# 3038
# 58.52
#
#
#
# 3039
# 69.11
#
#
#
# 3040
# 80.54
#
#
#
# 3041
# 74.2
#
#
#
# 3042
# 63.79
#
#
#
# 3043
# 75.14
#
#
#
# 3044
# 82.0
#
#
#
# 3045
# 43.3
#
#
#
# 3046
# 88.23
#
#
#
# 3047
# 67.29
#
#
#
# 3048
# 77.96
#
#
#
# 3049
# 88.76
#
#
#
# 3050
# 52.8
#
#
#
# 3051
# 62.07
#
#
#
# 3052
# 67.96
#
#
#
# 3053
# 61.03
#
#
#
# 3054
# 96.29
#
#
#
# 3055
# 60.01
#
#
#
# 3056
# 64.22
#
#
#
# 3057
# 74.86
#
#
#
# 3058
# 55.17
#
#
#
# 3059
# 66.46
#
#
#
# 3060
# 76.44
#
#
#
# 3061
# 67.34
#
#
#
# 3062
# 70.69
#
#
#
# 3063
# 64.59
#
#
#
# 3064
# 50.8
#
#
#
# 3065
# 76.5
#
#
#
# 3066
# 96.57
#
#
#
# 3067
# 72.26
#
#
#
# 3068
# 75.15
#
#
#
# 3069
# 81.7
#
#
#
# 3070
# 54.23
#
#
#
# 3071
# 95.84
#
#
#
# 3072
# 74.83
#
#
#
# 3073
# 94.85
#
#
#
# 3074
# 61.74
#
#
#
# 3075
# 97.45
#
#
#
# 3076
# 82.85
#
#
#
# 3077
# 79.74
#
#
#
# 3078
# 75.28
#
#
#
# 3079
# 68.52
#
#
#
# 3080
# 88.81
#
#
#
# 3081
# 73.97
#
#
#
# 3082
# 44.46
#
#
#
# 3083
# 56.36
#
#
#
# 3084
# 69.4
#
#
#
# 3085
# 76.34
#
#
#
# 3086
# 71.21
#
#
#
# 3087
# 89.07
#
#
#
# 3088
# 44.68
#
#
#
# 3089
# 74.01
#
#
#
# 3090
# 46.55
#
#
#
# 3091
# 82.64
#
#
#
# 3092
# 70.68
#
#
#
# 3093
# 77.87
#
#
#
# 3094
# 59.91
#
#
#
# 3095
# 89.91
#
#
#
# 3096
# 86.58
#
#
#
# 3097
# 80.17
#
#
#
# 3098
# 70.19
#
#
#
# 3099
# 80.12
#
#
#
# 3100
# 62.1
#
#
#
# 3101
# 83.98
#
#
#
# 3102
# 95.09
#
#
#
# 3103
# 86.99
#
#
#
# 3104
# 61.79
#
#
#
# 3105
# 77.06
#
#
#
# 3106
# 53.9
#
#
#
# 3107
# 80.01
#
#
#
# 3108
# 78.31
#
#
#
# 3109
# 45.82
#
#
#
# 3110
# 55.74
#
#
#
# 3111
# 68.04
#
#
#
# 3112
# 67.79
#
#
#
# 3113
# 55.07
#
#
#
# 3114
# 77.45
#
#
#
# 3115
# 75.52
#
#
#
# 3116
# 69.28
#
#
#
# 3117
# 61.42
#
#
#
# 3118
# 86.68
#
#
#
# 3119
# 95.18
#
#
#
# 3120
# 65.23
#
#
#
# 3121
# 63.43
#
#
#
# 3122
# 78.88
#
#
#
# 3123
# 66.99
#
#
#
# 3124
# 70.05
#
#
#
# 3125
# 82.36
#
#
#
# 3126
# 45.27
#
#
#
# 3127
# 90.46
#
#
#
# 3128
# 73.02
#
#
#
# 3129
# 66.24
#
#
#
# 3130
# 70.75
#
#
#
# 3131
# 71.47
#
#
#
# 3132
# 47.76
#
#
#
# 3133
# 92.93
#
#
#
# 3134
# 72.58
#
#
#
# 3135
# 78.2
#
#
#
# 3136
# 85.32
#
#
#
# 3137
# 57.7
#
#
#
# 3138
# 78.63
#
#
#
# 3139
# 68.25
#
#
#
# 3140
# 83.85
#
#
#
# 3141
# 42.22
#
#
#
# 3142
# 70.61
#
#
#
# 3143
# 63.56
#
#
#
# 3144
# 78.05
#
#
#
# 3145
# 78.58
#
#
#
# 3146
# 62.09
#
#
#
# 3147
# 62.03
#
#
#
# 3148
# 70.45
#
#
#
# 3149
# 59.45
#
#
#
# 3150
# 83.79
#
#
#
# 3151
# 66.83
#
#
#
# 3152
# 31.3
#
#
#
# 3153
# 66.75
#
#
#
# 3154
# 57.46
#
#
#
# 3155
# 49.16
#
#
#
# 3156
# 54.68
#
#
#
# 3157
# 73.53
#
#
#
# 3158
# 90.6
#
#
#
# 3159
# 76.38
#
#
#
# 3160
# 63.51
#
#
#
# 3161
# 78.38
#
#
#
# 3162
# 65.57
#
#
#
# 3163
# 62.28
#
#
#
# 3164
# 55.84
#
#
#
# 3165
# 47.47
#
#
#
# 3166
# 66.54
#
#
#
# 3167
# 74.21
#
#
#
# 3168
# 70.65
#
#
#
# 3169
# 66.18
#
#
#
# 3170
# 58.76
#
#
#
# 3171
# 80.52
#
#
#
# 3172
# 53.56
#
#
#
# 3173
# 82.86
#
#
#
# 3174
# 57.97
#
#
#
# 3175
# 61.47
#
#
#
# 3176
# 51.47
#
#
#
# 3177
# 64.98
#
#
#
# 3178
# 85.65
#
#
#
# 3179
# 79.22
#
#
#
# 3180
# 85.7
#
#
#
# 3181
# 79.31
#
#
#
# 3182
# 56.55
#
#
#
# 3183
# 67.37
#
#
#
# 3184
# 61.08
#
#
#
# 3185
# 90.63
#
#
#
# 3186
# 55.24
#
#
#
# 3187
# 84.51
#
#
#
# 3188
# 84.5
#
#
#
# 3189
# 97.61
#
#
#
# 3190
# 66.26
#
#
#
# 3191
# 81.97
#
#
#
# 3192
# 100.0
#
#
#
# 3193
# 63.35
#
#
#
# 3194
# 50.51
#
#
#
# 3195
# 45.68
#
#
#
# 3196
# 81.98
#
#
#
# 3197
# 45.64
#
#
#
# 3198
# 66.79
#
#
#
# 3199
# 78.12
#
#
#
# 3200
# 74.59
#
#
#
# 3201
# 77.96
#
#
#
# 3202
# 75.11
#
#
#
# 3203
# 89.9
#
#
#
# 3204
# 58.67
#
#
#
# 3205
# 62.52
#
#
#
# 3206
# 61.18
#
#
#
# 3207
# 83.62
#
#
#
# 3208
# 84.61
#
#
#
# 3209
# 78.32
#
#
#
# 3210
# 88.57
#
#
#
# 3211
# 55.51
#
#
#
# 3212
# 95.34
#
#
#
# 3213
# 93.33
#
#
#
# 3214
# 82.3
#
#
#
# 3215
# 96.95
#
#
#
# 3216
# 48.81
#
#
#
# 3217
# 64.66
#
#
#
# 3218
# 61.71
#
#
#
# 3219
# 82.1
#
#
#
# 3220
# 57.3
#
#
#
# 3221
# 82.6
#
#
#
# 3222
# 91.19
#
#
#
# 3223
# 81.73
#
#
#
# 3224
# 75.97
#
#
#
# 3225
# 58.17
#
#
#
# 3226
# 60.14
#
#
#
# 3227
# 89.49
#
#
#
# 3228
# 82.91
#
#
#
# 3229
# 71.45
#
#
#
# 3230
# 66.15
#
#
#
# 3231
# 43.64
#
#
#
# 3232
# 57.01
#
#
#
# 3233
# 98.76
#
#
#
# 3234
# 54.07
#
#
#
# 3235
# 74.65
#
#
#
# 3236
# 86.1
#
#
#
# 3237
# 54.43
#
#
#
# 3238
# 74.59
#
#
#
# 3239
# 85.13
#
#
#
# 3240
# 72.17
#
#
#
# 3241
# 100.0
#
#
#
# 3242
# 48.64
#
#
#
# 3243
# 86.82
#
#
#
# 3244
# 69.58
#
#
#
# 3245
# 82.81
#
#
#
# 3246
# 78.18
#
#
#
# 3247
# 61.74
#
#
#
# 3248
# 75.21
#
#
#
# 3249
# 45.99
#
#
#
# 3250
# 80.45
#
#
#
# 3251
# 76.17
#
#
#
# 3252
# 80.94
#
#
#
# 3253
# 86.81
#
#
#
# 3254
# 77.15
#
#
#
# 3255
# 74.07
#
#
#
# 3256
# 59.67
#
#
#
# 3257
# 62.03
#
#
#
# 3258
# 88.61
#
#
#
# 3259
# 92.11
#
#
#
# 3260
# 68.67
#
#
#
# 3261
# 72.64
#
#
#
# 3262
# 59.34
#
#
#
# 3263
# 88.42
#
#
#
# 3264
# 81.32
#
#
#
# 3265
# 99.18
#
#
#
# 3266
# 59.7
#
#
#
# 3267
# 66.71
#
#
#
# 3268
# 75.24
#
#
#
# 3269
# 81.05
#
#
#
# 3270
# 68.98
#
#
#
# 3271
# 59.78
#
#
#
# 3272
# 84.34
#
#
#
# 3273
# 82.1
#
#
#
# 3274
# 59.17
#
#
#
# 3275
# 90.98
#
#
#
# 3276
# 88.38
#
#
#
# 3277
# 73.88
#
#
#
# 3278
# 73.11
#
#
#
# 3279
# 79.76
#
#
#
# 3280
# 59.94
#
#
#
# 3281
# 72.42
#
#
#
# 3282
# 41.87
#
#
#
# 3283
# 84.27
#
#
#
# 3284
# 50.14
#
#
#
# 3285
# 93.05
#
#
#
# 3286
# 67.38
#
#
#
# 3287
# 69.04
#
#
#
# 3288
# 63.21
#
#
#
# 3289
# 67.97
#
#
#
# 3290
# 91.86
#
#
#
# 3291
# 37.17
#
#
#
# 3292
# 89.88
#
#
#
# 3293
# 76.73
#
#
#
# 3294
# 55.1
#
#
#
# 3295
# 56.95
#
#
#
# 3296
# 95.47
#
#
#
# 3297
# 58.76
#
#
#
# 3298
# 55.85
#
#
#
# 3299
# 87.92
#
#
#
# 3300
# 76.74
#
#
#
# 3301
# 58.87
#
#
#
# 3302
# 75.03
#
#
#
# 3303
# 57.64
#
#
#
# 3304
# 87.41
#
#
#
# 3305
# 86.86
#
#
#
# 3306
# 79.45
#
#
#
# 3307
# 77.06
#
#
#
# 3308
# 96.66
#
#
#
# 3309
# 72.0
#
#
#
# 3310
# 55.45
#
#
#
# 3311
# 78.29
#
#
#
# 3312
# 100.0
#
#
#
# 3313
# 57.79
#
#
#
# 3314
# 66.94
#
#
#
# 3315
# 77.83
#
#
#
# 3316
# 71.25
#
#
#
# 3317
# 58.25
#
#
#
# 3318
# 87.71
#
#
#
# 3319
# 100.0
#
#
#
# 3320
# 74.75
#
#
#
# 3321
# 59.34
#
#
#
# 3322
# 50.31
#
#
#
# 3323
# 75.61
#
#
#
# 3324
# 87.45
#
#
#
# 3325
# 78.65
#
#
#
# 3326
# 71.97
#
#
#
# 3327
# 63.75
#
#
#
# 3328
# 56.71
#
#
#
# 3329
# 83.69
#
#
#
# 3330
# 84.79
#
#
#
# 3331
# 50.36
#
#
#
# 3332
# 94.26
#
#
#
# 3333
# 80.04
#
#
#
# 3334
# 91.59
#
#
#
# 3335
# 53.21
#
#
#
# 3336
# 52.88
#
#
#
# 3337
# 69.91
#
#
#
# 3338
# 79.04
#
#
#
# 3339
# 97.15
#
#
#
# 3340
# 81.89
#
#
#
# 3341
# 68.6
#
#
#
# 3342
# 57.63
#
#
#
# 3343
# 89.22
#
#
#
# 3344
# 58.49
#
#
#
# 3345
# 94.8
#
#
#
# 3346
# 68.02
#
#
#
# 3347
# 94.27
#
#
#
# 3348
# 81.51
#
#
#
# 3349
# 70.08
#
#
#
# 3350
# 64.73
#
#
#
# 3351
# 67.23
#
#
#
# 3352
# 78.0
#
#
#
# 3353
# 73.08
#
#
#
# 3354
# 63.69
#
#
#
# 3355
# 69.68
#
#
#
# 3356
# 73.1
#
#
#
# 3357
# 42.2
#
#
#
# 3358
# 78.41
#
#
#
# 3359
# 58.28
#
#
#
# 3360
# 55.85
#
#
#
# 3361
# 48.38
#
#
#
# 3362
# 46.89
#
#
#
# 3363
# 53.02
#
#
#
# 3364
# 62.07
#
#
#
# 3365
# 99.35
#
#
#
# 3366
# 64.64
#
#
#
# 3367
# 74.49
#
#
#
# 3368
# 77.61
#
#
#
# 3369
# 73.83
#
#
#
# 3370
# 70.92
#
#
#
# 3371
# 55.27
#
#
#
# 3372
# 92.31
#
#
#
# 3373
# 97.3
#
#
#
# 3374
# 48.44
#
#
#
# 3375
# 57.66
#
#
#
# 3376
# 68.08
#
#
#
# 3377
# 58.5
#
#
#
# 3378
# 79.08
#
#
#
# 3379
# 61.8
#
#
#
# 3380
# 100.0
#
#
#
# 3381
# 88.67
#
#
#
# 3382
# 74.98
#
#
#
# 3383
# 86.38
#
#
#
# 3384
# 87.48
#
#
#
# 3385
# 64.1
#
#
#
# 3386
# 60.57
#
#
#
# 3387
# 73.09
#
#
#
# 3388
# 84.06
#
#
#
# 3389
# 73.95
#
#
#
# 3390
# 49.92
#
#
#
# 3391
# 60.76
#
#
#
# 3392
# 70.96
#
#
#
# 3393
# 70.94
#
#
#
# 3394
# 99.62
#
#
#
# 3395
# 52.6
#
#
#
# 3396
# 79.08
#
#
#
# 3397
# 92.85
#
#
#
# 3398
# 100.0
#
#
#
# 3399
# 66.34
#
#
#
# 3400
# 78.88
#
#
#
# 3401
# 79.98
#
#
#
# 3402
# 74.74
#
#
#
# 3403
# 70.62
#
#
#
# 3404
# 78.1
#
#
#
# 3405
# 36.55
#
#
#
# 3406
# 81.55
#
#
#
# 3407
# 73.77
#
#
#
# 3408
# 68.89
#
#
#
# 3409
# 100.0
#
#
#
# 3410
# 62.55
#
#
#
# 3411
# 66.36
#
#
#
# 3412
# 99.88
#
#
#
# 3413
# 60.35
#
#
#
# 3414
# 64.3
#
#
#
# 3415
# 69.94
#
#
#
# 3416
# 83.77
#
#
#
# 3417
# 74.91
#
#
#
# 3418
# 53.9
#
#
#
# 3419
# 64.55
#
#
#
# 3420
# 63.5
#
#
#
# 3421
# 70.92
#
#
#
# 3422
# 77.96
#
#
#
# 3423
# 77.85
#
#
#
# 3424
# 47.14
#
#
#
# 3425
# 86.9
#
#
#
# 3426
# 75.54
#
#
#
# 3427
# 91.38
#
#
#
# 3428
# 78.22
#
#
#
# 3429
# 87.42
#
#
#
# 3430
# 78.53
#
#
#
# 3431
# 90.85
#
#
#
# 3432
# 79.31
#
#
#
# 3433
# 70.63
#
#
#
# 3434
# 100.0
#
#
#
# 3435
# 84.45
#
#
#
# 3436
# 80.03
#
#
#
# 3437
# 54.13
#
#
#
# 3438
# 53.96
#
#
#
# 3439
# 76.1
#
#
#
# 3440
# 74.04
#
#
#
# 3441
# 63.4
#
#
#
# 3442
# 73.97
#
#
#
# 3443
# 94.24
#
#
#
# 3444
# 81.74
#
#
#
# 3445
# 56.03
#
#
#
# 3446
# 70.44
#
#
#
# 3447
# 60.73
#
#
#
# 3448
# 66.57
#
#
#
# 3449
# 66.21
#
#
#
# 3450
# 65.31
#
#
#
# 3451
# 54.43
#
#
#
# 3452
# 70.21
#
#
#
# 3453
# 64.15
#
#
#
# 3454
# 30.99
#
#
#
# 3455
# 100.0
#
#
#
# 3456
# 87.24
#
#
#
# 3457
# 66.73
#
#
#
# 3458
# 72.26
#
#
#
# 3459
# 55.6
#
#
#
# 3460
# 95.74
#
#
#
# 3461
# 98.56
#
#
#
# 3462
# 74.19
#
#
#
# 3463
# 86.33
#
#
#
# 3464
# 74.45
#
#
#
# 3465
# 53.29
#
#
#
# 3466
# 66.23
#
#
#
# 3467
# 73.85
#
#
#
# 3468
# 65.64
#
#
#
# 3469
# 68.94
#
#
#
# 3470
# 70.72
#
#
#
# 3471
# 70.87
#
#
#
# 3472
# 72.73
#
#
#
# 3473
# 57.15
#
#
#
# 3474
# 61.96
#
#
#
# 3475
# 54.02
#
#
#
# 3476
# 85.69
#
#
#
# 3477
# 42.52
#
#
#
# 3478
# 88.15
#
#
#
# 3479
# 91.41
#
#
#
# 3480
# 67.77
#
#
#
# 3481
# 35.56
#
#
#
# 3482
# 66.94
#
#
#
# 3483
# 71.1
#
#
#
# 3484
# 57.85
#
#
#
# 3485
# 64.79
#
#
#
# 3486
# 93.42
#
#
#
# 3487
# 81.31
#
#
#
# 3488
# 59.06
#
#
#
# 3489
# 49.63
#
#
#
# 3490
# 67.42
#
#
#
# 3491
# 69.01
#
#
#
# 3492
# 78.95
#
#
#
# 3493
# 64.51
#
#
#
# 3494
# 79.16
#
#
#
# 3495
# 99.09
#
#
#
# 3496
# 83.42
#
#
#
# 3497
# 71.33
#
#
#
# 3498
# 69.44
#
#
#
# 3499
# 67.01
#
#
#
# 3500
# 88.53
#
#
#
# 3501
# 63.22
#
#
#
# 3502
# 72.63
#
#
#
# 3503
# 72.72
#
#
#
# 3504
# 64.98
#
#
#
# 3505
# 52.79
#
#
#
# 3506
# 76.52
#
#
#
# 3507
# 71.15
#
#
#
# 3508
# 79.0
#
#
#
# 3509
# 64.53
#
#
#
# 3510
# 89.09
#
#
#
# 3511
# 59.73
#
#
#
# 3512
# 95.97
#
#
#
# 3513
# 47.53
#
#
#
# 3514
# 78.09
#
#
#
# 3515
# 78.66
#
#
#
# 3516
# 60.86
#
#
#
# 3517
# 77.94
#
#
#
# 3518
# 89.91
#
#
#
# 3519
# 40.96
#
#
#
# 3520
# 79.04
#
#
#
# 3521
# 37.09
#
#
#
# 3522
# 58.48
#
#
#
# 3523
# 94.81
#
#
#
# 3524
# 63.86
#
#
#
# 3525
# 55.57
#
#
#
# 3526
# 69.23
#
#
#
# 3527
# 100.0
#
#
#
# 3528
# 46.36
#
#
#
# 3529
# 57.28
#
#
#
# 3530
# 92.96
#
#
#
# 3531
# ...
# 65.52
#
#
#
# 3848
# 69.9
#
#
#
# 3849
# 51.94
#
#
#
# 3850
# 64.65
#
#
#
# 3851
# 78.91
#
#
#
# 3852
# 90.14
#
#
#
# 3853
# 56.5
#
#
#
# 3854
# 66.88
#
#
#
# 3855
# 69.88
#
#
#
# 3856
# 52.46
#
#
#
# 3857
# 80.28
#
#
#
# 3858
# 61.86
#
#
#
# 3859
# 69.26
#
#
#
# 3860
# 65.67
#
#
#
# 3861
# 60.95
#
#
#
# 3862
# 71.9
#
#
#
# 3863
# 68.98
#
#
#
# 3864
# 66.79
#
#
#
# 3865
# 61.8
#
#
#
# 3866
# 76.47
#
#
#
# 3867
# 95.15
#
#
#
# 3868
# 73.96
#
#
#
# 3869
# 85.95
#
#
#
# 3870
# 52.54
#
#
#
# 3871
# 74.21
#
#
#
# 3872
# 56.64
#
#
#
# 3873
# 51.32
#
#
#
# 3874
# 61.65
#
#
#
# 3875
# 88.69
#
#
#
# 3876
# 85.3
#
#
#
# 3877
# 75.4
#
#
#
# 3878
# 50.54
#
#
#
# 3879
# 69.25
#
#
#
# 3880
# 76.22
#
#
#
# 3881
# 74.46
#
#
#
# 3882
# 46.19
#
#
#
# 3883
# 59.54
#
#
#
# 3884
# 71.1
#
#
#
# 3885
# 79.51
#
#
#
# 3886
# 41.25
#
#
#
# 3887
# 69.73
#
#
#
# 3888
# 74.0
#
#
#
# 3889
# 83.89
#
#
#
# 3890
# 81.7
#
#
#
# 3891
# 80.16
#
#
#
# 3892
# 60.8
#
#
#
# 3893
# 45.29
#
#
#
# 3894
# 66.5
#
#
#
# 3895
# 86.02
#
#
#
# 3896
# 91.51
#
#
#
# 3897
# 81.95
#
#
#
# 3898
# 78.01
#
#
#
# 3899
# 77.31
#
#
#
# 3900
# 64.21
#
#
#
# 3901
# 70.18
#
#
#
# 3902
# 95.37
#
#
#
# 3903
# 58.8
#
#
#
# 3904
# 94.61
#
#
#
# 3905
# 67.49
#
#
#
# 3906
# 90.56
#
#
#
# 3907
# 52.3
#
#
#
# 3908
# 80.2
#
#
#
# 3909
# 61.69
#
#
#
# 3910
# 52.19
#
#
#
# 3911
# 75.06
#
#
#
# 3912
# 86.13
#
#
#
# 3913
# 60.17
#
#
#
# 3914
# 51.01
#
#
#
# 3915
# 70.71
#
#
#
# 3916
# 70.78
#
#
#
# 3917
# 79.68
#
#
#
# 3918
# 85.29
#
#
#
# 3919
# 71.17
#
#
#
# 3920
# 97.98
#
#
#
# 3921
# 75.14
#
#
#
# 3922
# 67.15
#
#
#
# 3923
# 49.44
#
#
#
# 3924
# 68.32
#
#
#
# 3925
# 67.29
#
#
#
# 3926
# 85.44
#
#
#
# 3927
# 78.47
#
#
#
# 3928
# 55.49
#
#
#
# 3929
# 74.41
#
#
#
# 3930
# 81.4
#
#
#
# 3931
# 93.39
#
#
#
# 3932
# 84.43
#
#
#
# 3933
# 82.65
#
#
#
# 3934
# 72.84
#
#
#
# 3935
# 77.44
#
#
#
# 3936
# 89.49
#
#
#
# 3937
# 53.34
#
#
#
# 3938
# 67.11
#
#
#
# 3939
# 61.18
#
#
#
# 3940
# 77.31
#
#
#
# 3941
# 89.22
#
#
#
# 3942
# 63.64
#
#
#
# 3943
# 38.54
#
#
#
# 3944
# 66.23
#
#
#
# 3945
# 84.79
#
#
#
# 3946
# 79.53
#
#
#
# 3947
# 77.99
#
#
#
# 3948
# 68.08
#
#
#
# 3949
# 54.09
#
#
#
# 3950
# 79.21
#
#
#
# 3951
# 60.32
#
#
#
# 3952
# 100.0
#
#
#
# 3953
# 79.99
#
#
#
# 3954
# 63.87
#
#
#
# 3955
# 63.44
#
#
#
# 3956
# 70.7
#
#
#
# 3957
# 68.65
#
#
#
# 3958
# 87.64
#
#
#
# 3959
# 74.61
#
#
#
# 3960
# 61.76
#
#
#
# 3961
# 98.47
#
#
#
# 3962
# 72.69
#
#
#
# 3963
# 82.76
#
#
#
# 3964
# 63.48
#
#
#
# 3965
# 77.08
#
#
#
# 3966
# 76.36
#
#
#
# 3967
# 45.54
#
#
#
# 3968
# 100.0
#
#
#
# 3969
# 90.07
#
#
#
# 3970
# 66.44
#
#
#
# 3971
# 56.57
#
#
#
# 3972
# 76.87
#
#
#
# 3973
# 73.21
#
#
#
# 3974
# 76.98
#
#
#
# 3975
# 74.68
#
#
#
# 3976
# 79.09
#
#
#
# 3977
# 92.26
#
#
#
# 3978
# 79.95
#
#
#
# 3979
# 57.3
#
#
#
# 3980
# 91.08
#
#
#
# 3981
# 94.97
#
#
#
# 3982
# 100.0
#
#
#
# 3983
# 56.27
#
#
#
# 3984
# 75.4
#
#
#
# 3985
# 42.85
#
#
#
# 3986
# 79.74
#
#
#
# 3987
# 64.33
#
#
#
# 3988
# 98.93
#
#
#
# 3989
# 61.16
#
#
#
# 3990
# 48.35
#
#
#
# 3991
# 65.4
#
#
#
# 3992
# 44.34
#
#
#
# 3993
# 82.52
#
#
#
# 3994
# 43.09
#
#
#
# 3995
# 72.4
#
#
#
# 3996
# 42.91
#
#
#
# 3997
# 67.52
#
#
#
# 3998
# 95.01
#
#
#
# 3999
# 77.05
#
#
#
# 4000
# 59.91
#
#
#
# 4001
# 71.56
#
#
#
# 4002
# 72.25
#
#
#
# 4003
# 78.62
#
#
#
# 4004
# 52.86
#
#
#
# 4005
# 80.3
#
#
#
# 4006
# 34.14
#
#
#
# 4007
# 63.18
#
#
#
# 4008
# 65.16
#
#
#
# 4009
# 80.87
#
#
#
# 4010
# 72.32
#
#
#
# 4011
# 52.32
#
#
#
# 4012
# 58.21
#
#
#
# 4013
# 74.78
#
#
#
# 4014
# 70.89
#
#
#
# 4015
# 63.89
#
#
#
# 4016
# 65.27
#
#
#
# 4017
# 81.75
#
#
#
# 4018
# 64.75
#
#
#
# 4019
# 70.77
#
#
#
# 4020
# 100.0
#
#
#
# 4021
# 52.07
#
#
#
# 4022
# 46.07
#
#
#
# 4023
# 82.97
#
#
#
# 4024
# 62.5
#
#
#
# 4025
# 67.54
#
#
#
# 4026
# 61.06
#
#
#
# 4027
# 68.36
#
#
#
# 4028
# 94.38
#
#
#
# 4029
# 83.23
#
#
#
# 4030
# 84.07
#
#
#
# 4031
# 52.17
#
#
#
# 4032
# 55.88
#
#
#
# 4033
# 32.25
#
#
#
# 4034
# 60.67
#
#
#
# 4035
# 85.39
#
#
#
# 4036
# 79.24
#
#
#
# 4037
# 68.9
#
#
#
# 4038
# 71.69
#
#
#
# 4039
# 62.36
#
#
#
# 4040
# 74.87
#
#
#
# 4041
# 82.72
#
#
#
# 4042
# 49.38
#
#
#
# 4043
# 76.2
#
#
#
# 4044
# 85.05
#
#
#
# 4045
# 66.19
#
#
#
# 4046
# 81.81
#
#
#
# 4047
# 100.0
#
#
#
# 4048
# 70.54
#
#
#
# 4049
# 77.51
#
#
#
# 4050
# 61.67
#
#
#
# 4051
# 74.54
#
#
#
# 4052
# 78.44
#
#
#
# 4053
# 74.73
#
#
#
# 4054
# 57.72
#
#
#
# 4055
# 74.89
#
#
#
# 4056
# 92.47
#
#
#
# 4057
# 78.28
#
#
#
# 4058
# 85.47
#
#
#
# 4059
# 68.68
#
#
#
# 4060
# 82.5
#
#
#
# 4061
# 75.91
#
#
#
# 4062
# 58.69
#
#
#
# 4063
# 76.46
#
#
#
# 4064
# 58.12
#
#
#
# 4065
# 63.14
#
#
#
# 4066
# 74.65
#
#
#
# 4067
# 76.16
#
#
#
# 4068
# 55.35
#
#
#
# 4069
# 86.76
#
#
#
# 4070
# 80.01
#
#
#
# 4071
# 62.13
#
#
#
# 4072
# 50.47
#
#
#
# 4073
# 69.97
#
#
#
# 4074
# 65.76
#
#
#
# 4075
# 73.58
#
#
#
# 4076
# 66.92
#
#
#
# 4077
# 43.9
#
#
#
# 4078
# 66.56
#
#
#
# 4079
# 67.72
#
#
#
# 4080
# 80.87
#
#
#
# 4081
# 62.23
#
#
#
# 4082
# 95.5
#
#
#
# 4083
# 45.24
#
#
#
# 4084
# 90.36
#
#
#
# 4085
# 68.86
#
#
#
# 4086
# 84.03
#
#
#
# 4087
# 73.12
#
#
#
# 4088
# 87.95
#
#
#
# 4089
# 66.58
#
#
#
# 4090
# 56.62
#
#
#
# 4091
# 91.89
#
#
#
# 4092
# 70.41
#
#
#
# 4093
# 75.1
#
#
#
# 4094
# 89.29
#
#
#
# 4095
# 57.55
#
#
#
# 4096
# 80.34
#
#
#
# 4097
# 63.74
#
#
#
# 4098
# 70.15
#
#
#
# 4099
# 73.01
#
#
#
# 4100
# 51.0
#
#
#
# 4101
# 61.1
#
#
#
# 4102
# 90.92
#
#
#
# 4103
# 84.41
#
#
#
# 4104
# 71.12
#
#
#
# 4105
# 75.4
#
#
#
# 4106
# 67.88
#
#
#
# 4107
# 90.99
#
#
#
# 4108
# 69.2
#
#
#
# 4109
# 75.25
#
#
#
# 4110
# 88.04
#
#
#
# 4111
# 61.12
#
#
#
# 4112
# 93.82
#
#
#
# 4113
# 50.57
#
#
#
# 4114
# 94.81
#
#
#
# 4115
# 66.78
#
#
#
# 4116
# 68.6
#
#
#
# 4117
# 45.54
#
#
#
# 4118
# 65.63
#
#
#
# 4119
# 57.44
#
#
#
# 4120
# 63.49
#
#
#
# 4121
# 70.08
#
#
#
# 4122
# 85.41
#
#
#
# 4123
# 74.91
#
#
#
# 4124
# 76.31
#
#
#
# 4125
# 56.66
#
#
#
# 4126
# 59.67
#
#
#
# 4127
# 97.18
#
#
#
# 4128
# 61.71
#
#
#
# 4129
# 95.19
#
#
#
# 4130
# 68.6
#
#
#
# 4131
# 72.03
#
#
#
# 4132
# 86.99
#
#
#
# 4133
# 89.81
#
#
#
# 4134
# 70.45
#
#
#
# 4135
# 66.56
#
#
#
# 4136
# 71.22
#
#
#
# 4137
# 76.73
#
#
#
# 4138
# 84.48
#
#
#
# 4139
# 72.06
#
#
#
# 4140
# 80.66
#
#
#
# 4141
# 94.94
#
#
#
# 4142
# 77.34
#
#
#
# 4143
# 76.36
#
#
#
# 4144
# 50.74
#
#
#
# 4145
# 35.17
#
#
#
# 4146
# 77.44
#
#
#
# 4147
# 70.67
#
#
#
# 4148
# 64.79
#
#
#
# 4149
# 75.41
#
#
#
# 4150
# 71.15
#
#
#
# 4151
# 87.79
#
#
#
# 4152
# 73.21
#
#
#
# 4153
# 61.54
#
#
#
# 4154
# 85.86
#
#
#
# 4155
# 68.96
#
#
#
# 4156
# 79.37
#
#
#
# 4157
# 65.32
#
#
#
# 4158
# 62.9
#
#
#
# 4159
# 73.18
#
#
#
# 4160
# 72.18
#
#
#
# 4161
# 78.72
#
#
#
# 4162
# 68.24
#
#
#
# 4163
# 46.29
#
#
#
# 4164
# 65.94
#
#
#
# 4165
# 83.11
#
#
#
# 4166
# 67.84
#
#
#
# 4167
# 68.55
#
#
#
# 4168
# 85.81
#
#
#
# 4169
# 62.03
#
#
#
# 4170
# 50.4
#
#
#
# 4171
# 69.75
#
#
#
# 4172
# 65.22
#
#
#
# 4173
# 58.47
#
#
#
# 4174
# 69.54
#
#
#
# 4175
# 78.88
#
#
#
# 4176
# 71.87
#
#
#
# 4177
# 76.3
#
#
#
# 4178
# 97.39
#
#
#
# 4179
# 67.2
#
#
#
# 4180
# 75.9
#
#
#
# 4181
# 64.87
#
#
#
# 4182
# 60.15
#
#
#
# 4183
# 63.81
#
#
#
# 4184
# 65.3
#
#
#
# 4185
# 77.03
#
#
#
# 4186
# 100.0
#
#
#
# 4187
# 61.98
#
#
#
# 4188
# 66.17
#
#
#
# 4189
# 71.12
#
#
#
# 4190
# 77.54
#
#
#
# 4191
# 75.69
#
#
#
# 4192
# 89.98
#
#
#
# 4193
# 38.03
#
#
#
# 4194
# 38.58
#
#
#
# 4195
# 65.06
#
#
#
# 4196
# 87.36
#
#
#
# 4197
# 50.08
#
#
#
# 4198
# 29.89
#
#
#
# 4199
# 80.0
#
#
#
# 4200
# 75.41
#
#
#
# 4201
# 56.74
#
#
#
# 4202
# 58.2
#
#
#
# 4203
# 58.42
#
#
#
# 4204
# 73.55
#
#
#
# 4205
# 63.23
#
#
#
# 4206
# 78.92
#
#
#
# 4207
# 32.04
#
#
#
# 4208
# 60.0
#
#
#
# 4209
# 56.24
#
#
#
# 4210
# 68.41
#
#
#
# 4211
# 64.47
#
#
#
# 4212
# 83.17
#
#
#
# 4213
# 45.97
#
#
#
# 4214
# 72.64
#
#
#
# 4215
# 79.82
#
#
#
# 4216
# 97.99
#
#
#
# 4217
# 65.26
#
#
#
# 4218
# 76.54
#
#
#
# 4219
# 46.75
#
#
#
# 4220
# 38.51
#
#
#
# 4221
# 83.83
#
#
#
# 4222
# 71.92
#
#
#
# 4223
# 88.5
#
#
#
# 4224
# 52.77
#
#
#
# 4225
# 79.28
#
#
#
# 4226
# 98.16
#
#
#
# 4227
# 77.88
#
#
#
# 4228
# 75.87
#
#
#
# 4229
# 72.12
#
#
#
# 4230
# 50.01
#
#
#
# 4231
# 90.98
#
#
#
# 4232
# 63.45
#
#
#
# 4233
# 79.06
#
#
#
# 4234
# 50.12
#
#
#
# 4235
# 55.49
#
#
#
# 4236
# 92.09
#
#
#
# 4237
# 67.14
#
#
#
# 4238
# 92.35
#
#
#
# 4239
# 70.9
#
#
#
# 4240
# 46.21
#
#
#
# 4241
# 84.49
#
#
#
# 4242
# 63.74
#
#
#
# 4243
# 81.78
#
#
#
# 4244
# 72.35
#
#
#
# 4245
# 50.4
#
#
#
# 4246
# 74.3
#
#
#
# 4247
# 100.0
#
#
#
# 4248
# 78.9
#
#
#
# 4249
# 71.19
#
#
#
# 4250
# 87.05
#
#
#
# 4251
# 74.95
#
#
#
# 4252
# 74.93
#
#
#
# 4253
# 56.72
#
#
#
# 4254
# 75.27
#
#
#
# 4255
# 86.5
#
#
#
# 4256
# 60.3
#
#
#
# 4257
# 91.94
#
#
#
# 4258
# 70.72
#
#
#
# 4259
# 59.57
#
#
#
# 4260
# 85.97
#
#
#
# 4261
# 67.98
#
#
#
# 4262
# 82.63
#
#
#
# 4263
# 67.92
#
#
#
# 4264
# 71.16
#
#
#
# 4265
# 78.91
#
#
#
# 4266
# 76.07
#
#
#
# 4267
# 44.06
#
#
#
# 4268
# 56.3
#
#
#
# 4269
# 85.01
#
#
#
# 4270
# 70.15
#
#
#
# 4271
# 64.67
#
#
#
# 4272
# 52.98
#
#
#
# 4273
# 56.88
#
#
#
# 4274
# 43.69
#
#
#
# 4275
# 70.58
#
#
#
# 4276
# 63.62
#
#
#
# 4277
# 58.47
#
#
#
# 4278
# 71.05
#
#
#
# 4279
# 77.1
#
#
#
# 4280
# 100.0
#
#
#
# 4281
# 50.83
#
#
#
# 4282
# 88.23
#
#
#
# 4283
# 85.62
#
#
#
# 4284
# 61.09
#
#
#
# 4285
# 74.85
#
#
#
# 4286
# 65.59
#
#
#
# 4287
# 74.6
#
#
#
# 4288
# 93.13
#
#
#
# 4289
# 80.48
#
#
#
# 4290
# 79.12
#
#
#
# 4291
# 65.98
#
#
#
# 4292
# 51.22
#
#
#
# 4293
# 69.08
#
#
#
# 4294
# 88.89
#
#
#
# 4295
# 50.62
#
#
#
# 4296
# 57.23
#
#
#
# 4297
# 73.77
#
#
#
# 4298
# 58.21
#
#
#
# 4299
# 60.9
#
#
#
# 4300
# 66.07
#
#
#
# 4301
# 52.88
#
#
#
# 4302
# 58.36
#
#
#
# 4303
# 81.85
#
#
#
# 4304
# 53.7
#
#
#
# 4305
# 49.63
#
#
#
# 4306
# 63.18
#
#
#
# 4307
# 82.25
#
#
#
# 4308
# 69.24
#
#
#
# 4309
# 65.5
#
#
#
# 4310
# 72.62
#
#
#
# 4311
# 47.56
#
#
#
# 4312
# 78.93
#
#
#
# 4313
# 77.37
#
#
#
# 4314
# 66.27
#
#
#
# 4315
# 86.08
#
#
#
# 4316
# 56.22
#
#
#
# 4317
# 87.79
#
#
#
# 4318
# 74.16
#
#
#
# 4319
# 67.29
#
#
#
# 4320
# 71.72
#
#
#
# 4321
# 70.5
#
#
#
# 4322
# 89.08
#
#
#
# 4323
# 56.93
#
#
#
# 4324
# 61.32
#
#
#
# 4325
# 86.51
#
#
#
# 4326
# 63.66
#
#
#
# 4327
# 84.61
#
#
#
# 4328
# 95.79
#
#
#
# 4329
# 66.37
#
#
#
# 4330
# 81.54
#
#
#
# 4331
# 55.85
#
#
#
# 4332
# 82.57
#
#
#
# 4333
# 74.79
#
#
#
# 4334
# 78.62
#
#
#
# 4335
# 62.96
#
#
#
# 4336
# 48.74
#
#
#
# 4337
# 79.05
#
#
#
# 4338
# 43.11
#
#
#
# 4339
# 67.56
#
#
#
# 4340
# 85.18
#
#
#
# 4341
# 74.69
#
#
#
# 4342
# 99.28
#
#
#
# 4343
# 86.35
#
#
#
# 4344
# 62.85
#
#
#
# 4345
# 72.38
#
#
#
# 4346
# 71.34
#
#
#
# 4347
# 49.85
#
#
#
# 4348
# 58.83
#
#
#
# 4349
# 64.15
#
#
#
# 4350
# 43.49
#
#
#
# 4351
# 72.66
#
#
#
# 4352
# 68.51
#
#
#
# 4353
# 48.58
#
#
#
# 4354
# 77.66
#
#
#
# 4355
# 82.02
#
#
#
# 4356
# 75.18
#
#
#
# 4357
# 67.46
#
#
#
# 4358
# 80.28
#
#
#
# 4359
# 81.52
#
#
#
# 4360
# 76.3
#
#
#
# 4361
# 60.46
#
#
#
# 4362
# 75.87
#
#
#
# 4363
# 88.74
#
#
#
# 4364
# 63.65
#
#
#
# 4365
# 100.0
#
#
#
# 4366
# 64.64
#
#
#
# 4367
# 72.45
#
#
#
# 4368
# 62.59
#
#
#
# 4369
# 75.13
#
#
#
# 4370
# 47.61
#
#
#
# 4371
# 64.36
#
#
#
# 4372
# 56.71
#
#
#
# 4373
# 73.89
#
#
#
# 4374
# 85.92
#
#
#
# 4375
# 81.04
#
#
#
# 4376
# 38.8
#
#
#
# 4377
# 100.0
#
#
#
# 4378
# 76.13
#
#
#
# 4379
# 61.13
#
#
#
# 4380
# 74.2
#
#
#
# 4381
# 74.47
#
#
#
# 4382
# 62.66
#
#
#
# 4383
# 74.77
#
#
#
# 4384
# 63.5
#
#
#
# 4385
# 66.34
#
#
#
# 4386
# 62.39
#
#
#
# 4387
# 51.94
#
#
#
# 4388
# 74.04
#
#
#
# 4389
# 80.19
#
#
#
# 4390
# 79.21
#
#
#
# 4391
# 83.48
#
#
#
# 4392
# 76.54
#
#
#
# 4393
# 64.54
#
#
#
# 4394
# 83.76
#
#
#
# 4395
# 52.99
#
#
#
# 4396
# 59.39
#
#
#
# 4397
# 58.5
#
#
#
# 4398
# 87.12
#
#
#
# 4399
# 85.2
#
#
#
# 4400
# 78.82
#
#
#
# 4401
# 87.01
#
#
#
# 4402
# 59.69
#
#
#
# 4403
# 76.88
#
#
#
# 4404
# 70.25
#
#
#
# 4405
# 83.86
#
#
#
# 4406
# 70.39
#
#
#
# 4407
# 66.61
#
#
#
# 4408
# 79.57
#
#
#
# 4409
# 84.27
#
#
#
# 4410
# 62.64
#
#
#
# 4411
# 71.14
#
#
#
# 4412
# 57.18
#
#
#
# 4413
# 37.03
#
#
#
# 4414
# 74.81
#
#
#
# 4415
# 80.52
#
#
#
# 4416
# 75.67
#
#
#
# 4417
# 44.71
#
#
#
# 4418
# 67.09
#
#
#
# 4419
# 40.94
#
#
#
# 4420
# 91.18
#
#
#
# 4421
# 56.8
#
#
#
# 4422
# 89.58
#
#
#
# 4423
# 85.24
#
#
#
# 4424
# 59.39
#
#
#
# 4425
# 56.14
#
#
#
# 4426
# 76.91
#
#
#
# 4427
# 60.18
#
#
#
# 4428
# 73.43
#
#
#
# 4429
# 65.24
#
#
#
# 4430
# 47.06
#
#
#
# 4431
# 40.77
#
#
#
# 4432
# 75.17
#
#
#
# 4433
# 64.14
#
#
#
# 4434
# 64.26
#
#
#
# 4435
# 81.74
#
#
#
# 4436
# 88.43
#
#
#
# 4437
# 68.18
#
#
#
# 4438
# 67.23
#
#
#
# 4439
# 79.0
#
#
#
# 4440
# 53.0
#
#
#
# 4441
# 75.12
#
#
#
# 4442
# 79.73
#
#
#
# 4443
# 81.52
#
#
#
# 4444
# 44.89
#
#
#
# 4445
# 61.34
#
#
#
# 4446
# 59.7
#
#
#
# 4447
# 73.4
#
#
#
# 4448
# 78.73
#
#
#
# 4449
# 92.95
#
#
#
# 4450
# 65.07
#
#
#
# 4451
# 65.03
#
#
#
# 4452
# 88.1
#
#
#
# 4453
# 76.15
#
#
#
# 4454
# 89.75
#
#
#
# 4455
# 76.04
#
#
#
# 4456
# 55.8
#
#
#
# 4457
# 53.34
#
#
#
# 4458
# 50.28
#
#
#
# 4459
# 81.27
#
#
#
# 4460
# 88.64
#
#
#
# 4461
# 97.89
#
#
#
# 4462
# 83.8
#
#
#
# 4463
# 88.28
#
#
#
# 4464
# 63.88
#
#
#
# 4465
# 55.81
#
#
#
# 4466
# 83.9
#
#
#
# 4467
# 77.85
#
#
#
# 4468
# 73.5
#
#
#
# 4469
# 77.42
#
#
#
# 4470
# 76.52
#
#
#
# 4471
# 89.97
#
#
#
# 4472
# 90.13
#
#
#
# 4473
# 79.62
#
#
#
# 4474
# 83.84
#
#
#
# 4475
# 79.2
#
#
#
# 4476
# 65.54
#
#
#
# 4477
# 82.59
#
#
#
# 4478
# 52.48
#
#
#
# 4479
# 86.75
#
#
#
# 4480
# 55.28
#
#
#
# 4481
# 76.0
#
#
#
# 4482
# 60.17
#
#
#
# 4483
# 79.75
#
#
#
# 4484
# 71.53
#
#
#
# 4485
# 49.67
#
#
#
# 4486
# 77.89
#
#
#
# 4487
# 63.91
#
#
#
# 4488
# 84.34
#
#
#
# 4489
# 72.02
#
#
#
# 4490
# 77.54
#
#
#
# 4491
# 58.59
#
#
#
# 4492
# 63.75
#
#
#
# 4493
# 65.58
#
#
#
# 4494
# 83.99
#
#
#
# 4495
# 95.48
#
#
#
# 4496
# 60.73
#
#
#
# 4497
# 87.08
#
#
#
# 4498
# 41.62
#
#
#
# 4499
# 55.28
#
#
#
# 4500
# 58.58
#
#
#
# 4501
# 53.06
#
#
#
# 4502
# 49.83
#
#
#
# 4503
# 77.78
#
#
#
# 4504
# 69.0
#
#
#
# 4505
# 77.31
#
#
#
# 4506
# 81.67
#
#
#
# 4507
# 75.72
#
#
#
# 4508
# 81.21
#
#
#
# 4509
# 71.03
#
#
#
# 4510
# 55.38
#
#
#
# 4511
# 86.81
#
#
#
# 4512
# 63.75
#
#
#
# 4513
# 58.9
#
#
#
# 4514
# 69.51
#
#
#
# 4515
# 59.22
#
#
#
# 4516
# 66.16
#
#
#
# 4517
# 76.82
#
#
#
# 4518
# 76.88
#
#
#
# 4519
# 59.43
#
#
#
# 4520
# 65.17
#
#
#
# 4521
# 87.04
#
#
#
# 4522
# 78.95
#
#
#
# 4523
# 100.0
#
#
#
# 4524
# 88.52
#
#
#
# 4525
# 88.02
#
#
#
# 4526
# 52.57
#
#
#
# 4527
# 82.69
#
#
#
# 4528
# 71.26
#
#
#
# 4529
# 64.29
#
#
#
# 4530
# 74.35
#
#
#
# 4531
# 85.23
#
#
#
# 4532
# 79.01
#
#
#
# 4533
# 59.7
#
#
#
# 4534
# 82.39
#
#
#
# 4535
# 63.07
#
#
#
# 4536
# 75.03
#
#
#
# 4537
# 67.75
#
#
#
# 4538
# 68.94
#
#
#
# 4539
# 82.73
#
#
#
# 4540
# 57.44
#
#
#
# 4541
# 99.23
#
#
#
# 4542
# 46.5
#
#
#
# 4543
# 63.63
#
#
#
# 4544
# 77.18
#
#
#
# 4545
# 80.18
#
#
#
# 4546
# 70.59
#
#
#
# 4547
# 71.2
#
#
#
# 4548
# 77.75
#
#
#
# 4549
# 68.77
#
#
#
# 4550
# 91.5
#
#
#
# 4551
# 83.75
#
#
#
# 4552
# 84.22
#
#
#
# 4553
# 58.47
#
#
#
# 4554
# 70.89
#
#
#
# 4555
# 67.79
#
#
#
# 4556
# 57.92
#
#
#
# 4557
# 77.04
#
#
#
# 4558
# 64.47
#
#
#
# 4559
# 81.18
#
#
#
# 4560
# 57.02
#
#
#
# 4561
# 96.07
#
#
#
# 4562
# 59.45
#
#
#
# 4563
# 75.07
#
#
#
# 4564
# 83.09
#
#
#
# 4565
# 64.01
#
#
#
# 4566
# 83.93
#
#
#
# 4567
# 54.79
#
#
#
# 4568
# 92.33
#
#
#
# 4569
# 72.2
#
#
#
# 4570
# 63.65
#
#
#
# 4571
# 67.81
#
#
#
# 4572
# 83.32
#
#
#
# 4573
# 63.82
#
#
#
# 4574
# 61.51
#
#
#
# 4575
# 68.9
#
#
#
# 4576
# 55.52
#
#
#
# 4577
# 97.49
#
#
#
# 4578
# 64.07
#
#
#
# 4579
# 83.64
#
#
#
# 4580
# 74.93
#
#
#
# 4581
# 58.22
#
#
#
# 4582
# 71.92
#
#
#
# 4583
# 82.98
#
#
#
# 4584
# 69.36
#
#
#
# 4585
# 88.7
#
#
#
# 4586
# 86.3
#
#
#
# 4587
# 84.86
#
#
#
# 4588
# 65.56
#
#
#
# 4589
# 56.88
#
#
#
# 4590
# 63.41
#
#
#
# 4591
# 74.75
#
#
#
# 4592
# 79.64
#
#
#
# 4593
# 41.6
#
#
#
# 4594
# 71.89
#
#
#
# 4595
# 74.21
#
#
#
# 4596
# 68.11
#
#
#
# 4597
# 90.08
#
#
#
# 4598
# 77.9
#
#
#
# 4599
# 90.34
#
#
#
# 4600
# 68.98
#
#
#
# 4601
# 85.12
#
#
#
# 4602
# 94.89
#
#
#
# 4603
# 90.36
#
#
#
# 4604
# 56.71
#
#
#
# 4605
# 68.45
#
#
#
# 4606
# 67.17
#
#
#
# 4607
# 78.85
#
#
#
# 4608
# 81.61
#
#
#
# 4609
# 60.26
#
#
#
# 4610
# 72.95
#
#
#
# 4611
# 43.72
#
#
#
# 4612
# 92.19
#
#
#
# 4613
# 64.83
#
#
#
# 4614
# 72.78
#
#
#
# 4615
# 67.66
#
#
#
# 4616
# 88.04
#
#
#
# 4617
# 32.27
#
#
#
# 4618
# 71.77
#
#
#
# 4619
# 70.52
#
#
#
# 4620
# 65.65
#
#
#
# 4621
# 96.17
#
#
#
# 4622
# 59.58
#
#
#
# 4623
# 82.81
#
#
#
# 4624
# 76.99
#
#
#
# 4625
# 89.66
#
#
#
# 4626
# 62.66
#
#
#
# 4627
# 61.74
#
#
#
# 4628
# 87.34
#
#
#
# 4629
# 77.95
#
#
#
# 4630
# 50.37
#
#
#
# 4631
# 64.45
#
#
#
# 4632
# 77.41
#
#
#
# 4633
# 83.73
#
#
#
# 4634
# 62.49
#
#
#
# 4635
# 31.2
#
#
#
# 4636
# 79.33
#
#
#
# 4637
# 54.92
#
#
#
# 4638
# 43.76
#
#
#
# 4639
# 32.35
#
#
#
# 4640
# 83.4
#
#
#
# 4641
# 73.8
#
#
#
# 4642
# 68.84
#
#
#
# 4643
# 91.45
#
#
#
# 4644
# 80.92
#
#
#
# 4645
# 94.63
#
#
#
# 4646
# 52.5
#
#
#
# 4647
# 71.52
#
#
#
# 4648
# 49.37
#
#
#
# 4649
# 68.79
#
#
#
# 4650
# 68.52
#
#
#
# 4651
# 80.77
#
#
#
# 4652
# 72.64
#
#
#
# 4653
# 80.73
#
#
#
# 4654
# 81.85
#
#
#
# 4655
# 100.0
#
#
#
# 4656
# 67.59
#
#
#
# 4657
# 58.83
#
#
#
# 4658
# 75.45
#
#
#
# 4659
# 60.77
#
#
#
# 4660
# 92.75
#
#
#
# 4661
# 68.03
#
#
#
# 4662
# 64.08
#
#
#
# 4663
# 65.4
#
#
#
# 4664
# 82.06
#
#
#
# 4665
# 69.79
#
#
#
# 4666
# 63.02
#
#
#
# 4667
# 95.31
#
#
#
# 4668
# 60.01
#
#
#
# 4669
# 72.5
#
#
#
# 4670
# 81.13
#
#
#
# 4671
# 49.16
#
#
#
# 4672
# 78.72
#
#
#
# 4673
# 57.23
#
#
#
# 4674
# 83.52
#
#
#
# 4675
# 58.52
#
#
#
# 4676
# 81.7
#
#
#
# 4677
# 87.48
#
#
#
# 4678
# 84.06
#
#
#
# 4679
# 75.52
#
#
#
# 4680
# 68.76
#
#
#
# 4681
# 63.93
#
#
#
# 4682
# 92.59
#
#
#
# 4683
# 62.21
#
#
#
# 4684
# 57.48
#
#
#
# 4685
# 81.32
#
#
#
# 4686
# 60.85
#
#
#
# 4687
# 58.7
#
#
#
# 4688
# 51.79
#
#
#
# 4689
# 65.24
#
#
#
# 4690
# 70.84
#
#
#
# 4691
# 75.4
#
#
#
# 4692
# 85.32
#
#
#
# 4693
# 79.38
#
#
#
# 4694
# 69.33
#
#
#
# 4695
# 69.23
#
#
#
# 4696
# 79.14
#
#
#
# 4697
# 89.82
#
#
#
# 4698
# 73.77
#
#
#
# 4699
# 65.43
#
#
#
# 4700
# 58.1
#
#
#
# 4701
# 51.77
#
#
#
# 4702
# 81.33
#
#
#
# 4703
# 80.09
#
#
#
# 4704
# 80.08
#
#
#
# 4705
# 70.2
#
#
#
# 4706
# 91.7
#
#
#
# 4707
# 65.22
#
#
#
# 4708
# 85.37
#
#
#
# 4709
# 71.46
#
#
#
# 4710
# 63.48
#
#
#
# 4711
# 80.3
#
#
#
# 4712
# 77.73
#
#
#
# 4713
# 77.0
#
#
#
# 4714
# 73.14
#
#
#
# 4715
# 71.47
#
#
#
# 4716
# 100.0
#
#
#
# 4717
# 88.58
#
#
#
# 4718
# 82.12
#
#
#
# 4719
# 73.57
#
#
#
# 4720
# 86.1
#
#
#
# 4721
# 79.25
#
#
#
# 4722
# 72.37
#
#
#
# 4723
# 67.75
#
#
#
# 4724
# 70.87
#
#
#
# 4725
# 27.61
#
#
#
# 4726
# 74.95
#
#
#
# 4727
# 65.16
#
#
#
# 4728
# 94.3
#
#
#
# 4729
# 72.27
#
#
#
# 4730
# 55.35
#
#
#
# 4731
# 71.3
#
#
#
# 4732
# 57.35
#
#
#
# 4733
# 78.63
#
#
#
# 4734
# 76.07
#
#
#
# 4735
# 85.41
#
#
#
# 4736
# 60.93
#
#
#
# 4737
# 72.48
#
#
#
# 4738
# 52.89
#
#
#
# 4739
# 81.82
#
#
#
# 4740
# 79.26
#
#
#
# 4741
# 78.94
#
#
#
# 4742
# 72.02
#
#
#
# 4743
# 77.81
#
#
#
# 4744
# 94.46
#
#
#
# 4745
# 68.01
#
#
#
# 4746
# 73.94
#
#
#
# 4747
# 56.79
#
#
#
# 4748
# 59.84
#
#
#
# 4749
# 73.37
#
#
#
# 4750
# 87.46
#
#
#
# 4751
# 68.41
#
#
#
# 4752
# 68.7
#
#
#
# 4753
# 66.3
#
#
#
# 4754
# 64.51
#
#
#
# 4755
# 76.13
#
#
#
# 4756
# 51.04
#
#
#
# 4757
# 89.93
#
#
#
# 4758
# 62.68
#
#
#
# 4759
# 82.11
#
#
#
# 4760
# 54.22
#
#
#
# 4761
# 81.36
#
#
#
# 4762
# 81.41
#
#
#
# 4763
# 77.38
#
#
#
# 4764
# 58.08
#
#
#
# 4765
# 75.49
#
#
#
# 4766
# 55.44
#
#
#
# 4767
# 68.46
#
#
#
# 4768
# 86.41
#
#
#
# 4769
# 83.15
#
#
#
# 4770
# 72.21
#
#
#
# 4771
# 58.35
#
#
#
# 4772
# 81.04
#
#
#
# 4773
# 72.27
#
#
#
# 4774
# 39.52
#
#
#
# 4775
# 82.96
#
#
#
# 4776
# 71.66
#
#
#
# 4777
# 88.83
#
#
#
# 4778
# 56.67
#
#
#
# 4779
# 27.53
#
#
#
# 4780
# 75.91
#
#
#
# 4781
# 76.08
#
#
#
# 4782
# 48.33
#
#
#
# 4783
# 58.3
#
#
#
# 4784
# 100.0
#
#
#
# 4785
# 67.72
#
#
#
# 4786
# 82.23
#
#
#
# 4787
# 62.89
#
#
#
# 4788
# 42.74
#
#
#
# 4789
# 69.62
#
#
#
# 4790
# 68.28
#
#
#
# 4791
# 66.4
#
#
#
# 4792
# 70.4
#
#
#
# 4793
# 75.7
#
#
#
# 4794
# 69.9
#
#
#
# 4795
# 54.3
#
#
#
# 4796
# 78.81
#
#
#
# 4797
# 44.71
#
#
#
# 4798
# 43.29
#
#
#
# 4799
# 82.35
#
#
#
# 4800
# 79.1
#
#
#
# 4801
# 71.2
#
#
#
# 4802
# 52.46
#
#
#
# 4803
# 62.09
#
#
#
# 4804
# 68.32
#
#
#
# 4805
# 49.66
#
#
#
# 4806
# 61.65
#
#
#
# 4807
# 81.13
#
#
#
# 4808
# 91.98
#
#
#
# 4809
# 66.13
#
#
#
# 4810
# 82.59
#
#
#
# 4811
# 45.2
#
#
#
# 4812
# 81.23
#
#
#
# 4813
# 60.74
#
#
#
# 4814
# 76.3
#
#
#
# 4815
# 68.53
#
#
#
# 4816
# 90.49
#
#
#
# 4817
# 59.76
#
#
#
# 4818
# 80.79
#
#
#
# 4819
# 68.09
#
#
#
# 4820
# 69.78
#
#
#
# 4821
# 69.43
#
#
#
# 4822
# 60.16
#
#
#
# 4823
# 71.8
#
#
#
# 4824
# 71.12
#
#
#
# 4825
# 75.38
#
#
#
# 4826
# 73.18
#
#
#
# 4827
# 83.17
#
#
#
# 4828
# 84.93
#
#
#
# 4829
# 57.29
#
#
#
# 4830
# 84.16
#
#
#
# 4831
# 55.39
#
#
#
# 4832
# 80.23
#
#
#
# 4833
# 80.68
#
#
#
# 4834
# 45.24
#
#
#
# 4835
# 73.3
#
#
#
# 4836
# 65.44
#
#
#
# 4837
# 61.38
#
#
#
# 4838
# 90.91
#
#
#
# 4839
# 62.85
#
#
#
# 4840
# 60.71
#
#
#
# 4841
# 73.06
#
#
#
# 4842
# 81.6
#
#
#
# 4843
# 70.02
#
#
#
# 4844
# 88.33
#
#
#
# 4845
# 79.43
#
#
#
# 4846
# 41.51
#
#
#
# 4847
# 64.59
#
#
#
# 4848
# 64.13
#
#
#
# 4849
# 78.71
#
#
#
# 4850
# 35.25
#
#
#
# 4851
# 100.0
#
#
#
# 4852
# 79.43
#
#
#
# 4853
# 74.08
#
#
#
# 4854
# 88.54
#
#
#
# 4855
# 100.0
#
#
#
# 4856
# 84.19
#
#
#
# 4857
# 85.28
#
#
#
# 4858
# 73.83
#
#
#
# 4859
# 70.02
#
#
#
# 4860
# 65.34
#
#
#
# 4861
# 60.43
#
#
#
# 4862
# 62.38
#
#
#
# 4863
# 53.09
#
#
#
# 4864
# 70.94
#
#
#
# 4865
# 48.41
#
#
#
# 4866
# 74.67
#
#
#
# 4867
# 71.49
#
#
#
# 4868
# 74.06
#
#
#
# 4869
# 64.69
#
#
#
# 4870
# 100.0
#
#
#
# 4871
# 91.04
#
#
#
# 4872
# 54.58
#
#
#
# 4873
# 75.26
#
#
#
# 4874
# 63.49
#
#
#
# 4875
# 57.8
#
#
#
# 4876
# 53.24
#
#
#
# 4877
# 78.05
#
#
#
# 4878
# 62.46
#
#
#
# 4879
# 85.55
#
#
#
# 4880
# 85.91
#
#
#
# 4881
# 91.23
#
#
#
# 4882
# 60.07
#
#
#
# 4883
# 78.66
#
#
#
# 4884
# 80.85
#
#
#
# 4885
# 65.36
#
#
#
# 4886
# 61.2
#
#
#
# 4887
# 94.53
#
#
#
# 4888
# 75.18
#
#
#
# 4889
# 80.9
#
#
#
# 4890
# 60.49
#
#
#
# 4891
# 54.93
#
#
#
# 4892
# 64.03
#
#
#
# 4893
# 70.26
#
#
#
# 4894
# 57.1
#
#
#
# 4895
# 71.86
#
#
#
# 4896
# 48.36
#
#
#
# 4897
# 56.32
#
#
#
# 4898
# 81.39
#
#
#
# 4899
# 80.45
#
#
#
# 4900
# 66.51
#
#
#
# 4901
# 57.75
#
#
#
# 4902
# 57.62
#
#
#
# 4903
# 66.77
#
#
#
# 4904
# 81.02
#
#
#
# 4905
# 85.0
#
#
#
# 4906
# 65.05
#
#
#
# 4907
# 55.85
#
#
#
# 4908
# 75.75
#
#
#
# 4909
# 60.47
#
#
#
# 4910
# 64.74
#
#
#
# 4911
# 90.55
#
#
#
# 4912
# 83.58
#
#
#
# 4913
# 74.21
#
#
#
# 4914
# 54.19
#
#
#
# 4915
# 74.96
#
#
#
# 4916
# 86.88
#
#
#
# 4917
# 66.74
#
#
#
# 4918
# 90.92
#
#
#
# 4919
# 90.1
#
#
#
# 4920
# 95.29
#
#
#
# 4921
# 76.27
#
#
#
# 4922
# 80.22
#
#
#
# 4923
# 91.8
#
#
#
# 4924
# 78.26
#
#
#
# 4925
# 64.98
#
#
#
# 4926
# 65.72
#
#
#
# 4927
# 75.34
#
#
#
# 4928
# 53.93
#
#
#
# 4929
# 69.99
#
#
#
# 4930
# 87.35
#
#
#
# 4931
# 41.32
#
#
#
# 4932
# 93.48
#
#
#
# 4933
# 87.71
#
#
#
# 4934
# 65.56
#
#
#
# 4935
# 79.61
#
#
#
# 4936
# 72.04
#
#
#
# 4937
# 89.22
#
#
#
# 4938
# 85.76
#
#
#
# 4939
# 52.4
#
#
#
# 4940
# 80.22
#
#
#
# 4941
# 69.12
#
#
#
# 4942
# 73.16
#
#
#
# 4943
# 61.81
#
#
#
# 4944
# 96.47
#
#
#
# 4945
# 86.56
#
#
#
# 4946
# 61.64
#
#
#
# 4947
# 53.32
#
#
#
# 4948
# 66.6
#
#
#
# 4949
# 78.08
#
#
#
# 4950
# 75.36
#
#
#
# 4951
# 89.54
#
#
#
# 4952
# 83.06
#
#
#
# 4953
# 85.57
#
#
#
# 4954
# 76.58
#
#
#
# 4955
# 52.55
#
#
#
# 4956
# 69.26
#
#
#
# 4957
# 86.84
#
#
#
# 4958
# 71.28
#
#
#
# 4959
# 79.04
#
#
#
# 4960
# 67.54
#
#
#
# 4961
# 57.58
#
#
#
# 4962
# 70.27
#
#
#
# 4963
# 76.33
#
#
#
# 4964
# 62.82
#
#
#
# 4965
# 68.7
#
#
#
# 4966
# 58.85
#
#
#
# 4967
# 87.67
#
#
#
# 4968
# 67.88
#
#
#
# 4969
# 92.34
#
#
#
# 4970
# 93.4
#
#
#
# 4971
# 70.87
#
#
#
# 4972
# 57.88
#
#
#
# 4973
# 42.8
#
#
#
# 4974
# 51.39
#
#
#
# 4975
# 52.77
#
#
#
# 4976
# 91.3
#
#
#
# 4977
# 73.62
#
#
#
# 4978
# 77.45
#
#
#
# 4979
# 40.91
#
#
#
# 4980
# 55.23
#
#
#
# 4981
# 84.42
#
#
#
# 4982
# 76.01
#
#
#
# 4983
# 69.94
#
#
#
# 4984
# 79.91
#
#
#
# 4985
# 94.9
#
#
#
# 4986
# 68.91
#
#
#
# 4987
# 72.97
#
#
#
# 4988
# 74.7
#
#
#
# 4989
# 100.0
#
#
#
# 4990
# 42.61
#
#
#
# 4991
# 81.57
#
#
#
# 4992
# 70.39
#
#
#
# 4993
# 79.93
#
#
#
# 4994
# 62.8
#
#
#
# 4995
# 71.31
#
#
#
# 4996
# 81.96
#
#
#
# 4997
# 100.0
#
#
#
# 4998
# 83.31
#
#
#
# 4999
# 60.13
