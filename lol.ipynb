# %% [markdown]
# # Data Visualization using Pandas
#
# ## Importing the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Intro to Dataframes

# %%
df = pd.DataFrame([[1,2],[4,5],[6,7]])
df
# Out:
#    0  1
# 0  1  2
# 1  4  5
# 2  6  7

# %%
df = pd.DataFrame([[1,2],[4,5],[6,7]], columns = ["A","B"])
df
# Out:
#    A  B
# 0  1  2
# 1  4  5

# %%
df = pd.DataFrame([[1,2],[4,5],[6,7]], columns = ["A","B"], index=["x","y","z"])
df
# Out:
#    A  B
# x  1  2
# y  4  5
# z  6  7

# %%
df.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %% [markdown]
# ### **Indices are the rows and columns are columns**
# #### You can use .tolist after index and columns to get it in list format

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.columns.tolist()
# Out:
# ['A', 'B']

# %%
df.head()
# Out:
#    A  B
# x  1  2
# y  4  5
# z  6  7

# %%
df.tail()
# Out:
#    A  B
# x  1  2
# y  4  5
# z  6  7

# %% [markdown]
# #### df.head() only gives the first 5 data rows and df.tail() gives the last 5

# %%
df.head(1)
# Out:
#    A  B
# x  1  2

# %%
df.head(2)
# Out:
#    A  B
# x  1  2
# y  4  5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0+ bytes

# %% [markdown]
# #### Gives information regarding the dataframe

# %%
df.describe()
# Out:
#               A         B
# count  3.000000  3.000000
# mean   3.666667  4.666667
# std    2.516611  2.516611
# min    1.000000  2.000000
# 25%    2.500000  3.500000
# 50%    4.000000  5.000000
# 75%    5.000000  6.000000
# max    6.000000  7.000000

# %% [markdown]
# #### Gives meaningful information regarding the dataframe

# %%
df.nunique()
# Out:
# A    3
# B    3
# dtype: int64

# %% [markdown]
# #### Gives the number of non unique values in each row
# #### can be specfically done on one row as well as shown

# %%
df['A'].nunique()
# Out:
# 3

# %%
df['A'].unique()
# Out:
# array([1, 4, 6], dtype=int64)

# %%
df.shape
# Out:
# (3, 2)

# %% [markdown]
# #### Gives the shape of the dataframe

# %%
df.size
# Out:
# 6

# %% [markdown]
# #### Total Number of spaces ( no. of rows multiplied by no. of columns)

# %% [markdown]
# ## To import the dataset from the excel file to the dataframe from PANDAS

# %%
jee = pd.read_csv('JEE_Dropout_After_Class_12.csv', delimiter=',')
jee.head()
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
# 4           68.72               77.73                82.37         CBSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
# 4             89.02              1              Allen                6.3
#
#   family_income parent_education location_type peer_pressure_level  \
# 0           Low        Upto 10th         Urban                 Low
# 1           Mid        Upto 10th         Urban                 Low
# 2           Low               PG    Semi-Urban              Medium
# 3           Low             12th    Semi-Urban              Medium
# 4           Mid         Graduate    Semi-Urban                High
#
#   mental_health_issues admission_taken  dropout
# 0                   No              No        1
# 1                  Yes              No        0
# 2                  Yes              No        1
# 3                  Yes             Yes        0
# 4                   No             Yes        0

# %% [markdown]
# #### pd.read_csv reads the csv file and enters it into a Dataframe called "df" and if it is a text file, instead of the delimiter being ',', you can put '\t'

# %%
jee.columns.tolist()
# Out:
# ['jee_main_score',
#  'jee_advanced_score',
#  'mock_test_score_avg',
#  'school_board',
#  'class_12_percent',
#  'attempt_count',
#  'coaching_institute',
#  'daily_study_hours',
#  'family_income',
#  'parent_education',
#  'location_type',
#  'peer_pressure_level',
#  'mental_health_issues',
#  'admission_taken',
#  'dropout']

# %% [markdown]
# ### code such as **jee.tocsv, jee.toparquet, jee.toexcel** will help us save the changes in the dataframe to the source file.

# %%
jee.sample(10)
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 3347           94.27               71.06                61.02         CBSE
# 1933           70.52               65.85                78.88         CBSE
# 1596           80.67               57.93                48.36         ICSE
# 979            82.65               73.78                72.58        State
# 2446           76.12               78.42                58.50         ICSE
# 767            96.79               64.72                86.95         ICSE
# 3332           94.26               68.40                73.87         ICSE
# 3323           75.61               92.26                68.22        State
# 2565           66.29               38.46                62.78         ICSE
# 2158           89.94               52.33                60.09        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 3347             74.98              2              Allen                4.0
# 1933             70.91              2              Local                1.9
# 1596             63.45              2            FIITJEE                6.4
# 979              78.01              1                NaN                8.3
# 2446             76.49              1              Local                4.1
# 767              88.06              1                NaN                6.6
# 3332             72.48              1                NaN                0.4
# 3323             61.38              2              Allen                4.4
# 2565             72.72              1              Allen                3.8
# 2158             86.89              1                NaN                5.9
#
#      family_income parent_education location_type peer_pressure_level  \
# 3347           Low         Graduate         Rural                High
# 1933           Low         Graduate    Semi-Urban              Medium
# 1596           Low             12th         Urban              Medium
# 979            Low               PG    Semi-Urban                High
# 2446           Low         Graduate         Urban                High
# 767            Mid        Upto 10th         Urban                High
# 3332          High             12th         Urban                High
# 3323           Mid         Graduate    Semi-Urban              Medium
# 2565          High             12th         Rural                High
# 2158           Low             12th         Rural              Medium
#
#      mental_health_issues admission_taken  dropout
# 3347                   No              No        1
# 1933                   No             Yes        0
# 1596                   No              No        1
# 979                    No              No        1
# 2446                  Yes             Yes        0
# 767                   Yes              No        0
# 3332                  Yes             Yes        1
# 3323                   No             Yes        0
# 2565                  Yes             Yes        0
# 2158                  Yes              No        1

# %% [markdown]
# #### .sample picks the required amount of rows from the dataframe. In the parameters, random_state="" helps act like a seed to lock in a selection of random picks

# %% [markdown]
# ## loc and iloc

# %% [markdown]
# ### The only difference between '.loc' and '.iloc' (Integer loc, only integers allowed) is that loc can hold the column names while iloc will only allow the index and column numbers to be used to select data
# ### **Another difference is that in '.loc', the upper limit is also included in the data while in '.iloc', it is not shown**

# %%
jee.loc[0]
# Out:
# jee_main_score              78.95
# jee_advanced_score          59.22
# mock_test_score_avg         59.86
# school_board                 CBSE
# class_12_percent            70.09
# attempt_count                   1
# coaching_institute        FIITJEE
# daily_study_hours             5.4
# family_income                 Low
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         1
# Name: 0, dtype: object

# %%
jee.loc[0:3]
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
#
#   family_income parent_education location_type peer_pressure_level  \
# 0           Low        Upto 10th         Urban                 Low
# 1           Mid        Upto 10th         Urban                 Low
# 2           Low               PG    Semi-Urban              Medium
# 3           Low             12th    Semi-Urban              Medium
#
#   mental_health_issues admission_taken  dropout
# 0                   No              No        1
# 1                  Yes              No        0
# 2                  Yes              No        1
# 3                  Yes             Yes        0

# %%
jee.loc[0:3,["jee_main_score","attempt_count"]]
# Out:
#    jee_main_score  attempt_count
# 0           78.95              1
# 1           70.06              1
# 2           81.07              1
# 3           93.32              1

# %%
jee.iloc[5:]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 5              68.72               45.61                58.75        State
# 6              94.11               82.78                80.01         CBSE
# 7              82.74               73.80                58.62         CBSE
# 8              65.43               54.25                57.83         ICSE
# 9              79.60               63.74                77.82        State
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 5                79.28              1              Local                4.5
# 6                76.31              1              Local                3.7
# 7                77.15              1                NaN                2.2
# 8                71.11              1              Local                5.7
# 9                94.96              2                NaN                2.7
# ...                ...            ...                ...                ...
# 4995             84.45              1            FIITJEE                4.7
# 4996             73.02              2              Local                4.7
# 4997             77.87              2                NaN                6.3
# 4998             62.25              1              Allen                4.0
# 4999             94.90              2            FIITJEE                2.1
#
#      family_income parent_education location_type peer_pressure_level  \
# 5              Mid         Graduate    Semi-Urban                 Low
# 6              Mid        Upto 10th    Semi-Urban              Medium
# 7             High             12th         Urban                 Low
# 8              Mid        Upto 10th    Semi-Urban                 Low
# 9              Mid             12th         Rural                High
# ...            ...              ...           ...                 ...
# 4995          High               PG    Semi-Urban                High
# 4996           Mid               PG         Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
# 4998          High        Upto 10th         Urban                 Low
# 4999           Mid             12th         Urban                 Low
#
#      mental_health_issues admission_taken  dropout
# 5                      No             Yes        0
# 6                      No             Yes        0
# 7                      No             Yes        0
# 8                      No             Yes        0
# 9                     Yes              No        0
# ...                   ...             ...      ...
# 4995                  Yes             Yes        0
# 4996                  Yes             Yes        0
# 4997                  Yes             Yes        0
# 4998                   No             Yes        0
# 4999                  Yes              No        0
#
# [4995 rows x 15 columns]

# %%
jee.iloc[0]
# Out:
# jee_main_score              78.95
# jee_advanced_score          59.22
# mock_test_score_avg         59.86
# school_board                 CBSE
# class_12_percent            70.09
# attempt_count                   1
# coaching_institute        FIITJEE
# daily_study_hours             5.4
# family_income                 Low
# parent_education        Upto 10th
# location_type               Urban
# peer_pressure_level           Low
# mental_health_issues           No
# admission_taken                No
# dropout                         1
# Name: 0, dtype: object

# %%
jee.iloc[0:3]
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
#
#   family_income parent_education location_type peer_pressure_level  \
# 0           Low        Upto 10th         Urban                 Low
# 1           Mid        Upto 10th         Urban                 Low
# 2           Low               PG    Semi-Urban              Medium
#
#   mental_health_issues admission_taken  dropout
# 0                   No              No        1
# 1                  Yes              No        0
# 2                  Yes              No        1

# %%
jee.iloc[0:2,["jee_main_score"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 jee.iloc[0:2,["jee_main_score"]]
#
# File c:\Users\chrch\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Users\chrch\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
#    1651 def _getitem_tuple(self, tup: tuple):
# -> 1652     tup = self._validate_tuple_indexer(tup)
#    1653     with suppress(IndexingError):
#    1654         return self._getitem_lowerdim(tup)
#
# File c:\Users\chrch\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:940, in _LocationIndexer._validate_tuple_indexer(self, key)
#     938 for i, k in enumerate(key):
#     939     try:
# --> 940         self._validate_key(k, i)
#     941     except ValueError as err:
#     942         raise ValueError(
#     943             "Location based indexing can only have "
#     944             f"[{self._valid_types}] types"
#     945         ) from err
#
# File c:\Users\chrch\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1570, in _iLocIndexer._validate_key(self, key, axis)
#    1568 # check that the key has a numeric dtype
#    1569 if not is_numeric_dtype(arr.dtype):
# -> 1570     raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1572 # check that the key does not exceed the maximum size of the index
#    1573 if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
#
# IndexError: .iloc requires numeric indexers, got ['jee_main_score']

# %%
jee.index=jee["school_board"]
jee
# Out:
#               jee_main_score  jee_advanced_score  mock_test_score_avg  \
# school_board
# CBSE                   78.95               59.22                59.86
# State                  70.06               58.75                64.33
# ICSE                   81.07               37.27                60.83
# ICSE                   93.32               60.72                69.33
# CBSE                   68.72               77.73                82.37
# ...                      ...                 ...                  ...
# State                  71.31               86.82                57.08
# CBSE                   81.96               34.03                82.85
# CBSE                  100.00               54.71                83.75
# CBSE                   83.31               73.93                57.39
# State                  60.13               76.31                66.15
#
#              school_board  class_12_percent  attempt_count coaching_institute  \
# school_board
# CBSE                 CBSE             70.09              1            FIITJEE
# State               State             78.00              1            FIITJEE
# ICSE                 ICSE             64.36              1            FIITJEE
# ICSE                 ICSE             73.21              1            FIITJEE
# CBSE                 CBSE             89.02              1              Allen
# ...                   ...               ...            ...                ...
# State               State             84.45              1            FIITJEE
# CBSE                 CBSE             73.02              2              Local
# CBSE                 CBSE             77.87              2                NaN
# CBSE                 CBSE             62.25              1              Allen
# State               State             94.90              2            FIITJEE
#
#               daily_study_hours family_income parent_education location_type  \
# school_board
# CBSE                        5.4           Low        Upto 10th         Urban
# State                       5.5           Mid        Upto 10th         Urban
# ICSE                        7.0           Low               PG    Semi-Urban
# ICSE                        2.1           Low             12th    Semi-Urban
# CBSE                        6.3           Mid         Graduate    Semi-Urban
# ...                         ...           ...              ...           ...
# State                       4.7          High               PG    Semi-Urban
# CBSE                        4.7           Mid               PG         Urban
# CBSE                        6.3           Mid               PG    Semi-Urban
# CBSE                        4.0          High        Upto 10th         Urban
# State                       2.1           Mid             12th         Urban
#
#              peer_pressure_level mental_health_issues admission_taken  dropout
# school_board
# CBSE                         Low                   No              No        1
# State                        Low                  Yes              No        0
# ICSE                      Medium                  Yes              No        1
# ICSE                      Medium                  Yes             Yes        0
# CBSE                        High                   No             Yes        0
# ...                          ...                  ...             ...      ...
# State                       High                  Yes             Yes        0
# CBSE                        High                  Yes             Yes        0
# CBSE                      Medium                  Yes             Yes        0
# CBSE                         Low                   No             Yes        0
# State                        Low                  Yes              No        0
#
# [5000 rows x 15 columns]

# %% [markdown]
# ### The Serial Numbers have been replaced with the curriculum board

# %%
jee.loc[["CBSE","ICSE","State"],"jee_main_score"]
# Out:
# school_board
# CBSE      78.95
# CBSE      68.72
# CBSE      94.11
# CBSE      82.74
# CBSE      65.51
#           ...
# State    100.00
# State     70.39
# State     62.80
# State     71.31
# State     60.13
# Name: jee_main_score, Length: 5000, dtype: float64

# %%
jee.loc[["CBSE","ICSE","State"],"jee_main_score"].iloc[0:8]
# Out:
# school_board
# CBSE    78.95
# CBSE    68.72
# CBSE    94.11
# CBSE    82.74
# CBSE    65.51
# CBSE    75.39
# CBSE    64.13
# CBSE    52.23
# Name: jee_main_score, dtype: float64

# %%
jee.reset_index(drop=True, inplace=True)
jee
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              70.06               58.75                64.33        State
# 2              81.07               37.27                60.83         ICSE
# 3              93.32               60.72                69.33         ICSE
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0                70.09              1            FIITJEE                5.4
# 1                78.00              1            FIITJEE                5.5
# 2                64.36              1            FIITJEE                7.0
# 3                73.21              1            FIITJEE                2.1
# 4                89.02              1              Allen                6.3
# ...                ...            ...                ...                ...
# 4995             84.45              1            FIITJEE                4.7
# 4996             73.02              2              Local                4.7
# 4997             77.87              2                NaN                6.3
# 4998             62.25              1              Allen                4.0
# 4999             94.90              2            FIITJEE                2.1
#
#      family_income parent_education location_type peer_pressure_level  \
# 0              Low        Upto 10th         Urban                 Low
# 1              Mid        Upto 10th         Urban                 Low
# 2              Low               PG    Semi-Urban              Medium
# 3              Low             12th    Semi-Urban              Medium
# 4              Mid         Graduate    Semi-Urban                High
# ...            ...              ...           ...                 ...
# 4995          High               PG    Semi-Urban                High
# 4996           Mid               PG         Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
# 4998          High        Upto 10th         Urban                 Low
# 4999           Mid             12th         Urban                 Low
#
#      mental_health_issues admission_taken  dropout
# 0                      No              No        1
# 1                     Yes              No        0
# 2                     Yes              No        1
# 3                     Yes             Yes        0
# 4                      No             Yes        0
# ...                   ...             ...      ...
# 4995                  Yes             Yes        0
# 4996                  Yes             Yes        0
# 4997                  Yes             Yes        0
# 4998                   No             Yes        0
# 4999                  Yes              No        0
#
# [5000 rows x 15 columns]

# %%
jee.groupby("school_board").first().loc[["CBSE", "ICSE", "State"], "jee_main_score"]
# Out:
# school_board
# CBSE     78.95
# ICSE     81.07
# State    70.06
# Name: jee_main_score, dtype: float64

# %% [markdown]
# ### Picks the first among the three curricula and displays the intended column

# %%
jee.groupby("school_board").apply(lambda x: x.sample(1))[["school_board", "jee_main_score"]].reset_index(drop=True)
# Out:
#   school_board  jee_main_score
# 0         CBSE           82.29
# 1         ICSE           45.73
# 2        State           55.23

# %% [markdown]
# ##### Upgraded version of the previous one
# ### Picks a random one among the three curricula and displays the intended column

# %% [markdown]
# ## What if we want to change a value somewhere in the dataframe?

# %%
jee
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              70.06               58.75                64.33        State
# 2              81.07               37.27                60.83         ICSE
# 3              93.32               60.72                69.33         ICSE
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0                70.09              1            FIITJEE                5.4
# 1                78.00              1            FIITJEE                5.5
# 2                64.36              1            FIITJEE                7.0
# 3                73.21              1            FIITJEE                2.1
# 4                89.02              1              Allen                6.3
# ...                ...            ...                ...                ...
# 4995             84.45              1            FIITJEE                4.7
# 4996             73.02              2              Local                4.7
# 4997             77.87              2                NaN                6.3
# 4998             62.25              1              Allen                4.0
# 4999             94.90              2            FIITJEE                2.1
#
#      family_income parent_education location_type peer_pressure_level  \
# 0              Low        Upto 10th         Urban                 Low
# 1              Mid        Upto 10th         Urban                 Low
# 2              Low               PG    Semi-Urban              Medium
# 3              Low             12th    Semi-Urban              Medium
# 4              Mid         Graduate    Semi-Urban                High
# ...            ...              ...           ...                 ...
# 4995          High               PG    Semi-Urban                High
# 4996           Mid               PG         Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
# 4998          High        Upto 10th         Urban                 Low
# 4999           Mid             12th         Urban                 Low
#
#      mental_health_issues admission_taken  dropout
# 0                      No              No        1
# 1                     Yes              No        0
# 2                     Yes              No        1
# 3                     Yes             Yes        0
# 4                      No             Yes        0
# ...                   ...             ...      ...
# 4995                  Yes             Yes        0
# 4996                  Yes             Yes        0
# 4997                  Yes             Yes        0
# 4998                   No             Yes        0
# 4999                  Yes              No        0
#
# [5000 rows x 15 columns]

# %%
jee.loc[1,"jee_main_score"] = 80
jee
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              80.00               58.75                64.33        State
# 2              81.07               37.27                60.83         ICSE
# 3              93.32               60.72                69.33         ICSE
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0                70.09              1            FIITJEE                5.4
# 1                78.00              1            FIITJEE                5.5
# 2                64.36              1            FIITJEE                7.0
# 3                73.21              1            FIITJEE                2.1
# 4                89.02              1              Allen                6.3
# ...                ...            ...                ...                ...
# 4995             84.45              1            FIITJEE                4.7
# 4996             73.02              2              Local                4.7
# 4997             77.87              2                NaN                6.3
# 4998             62.25              1              Allen                4.0
# 4999             94.90              2            FIITJEE                2.1
#
#      family_income parent_education location_type peer_pressure_level  \
# 0              Low        Upto 10th         Urban                 Low
# 1              Mid        Upto 10th         Urban                 Low
# 2              Low               PG    Semi-Urban              Medium
# 3              Low             12th    Semi-Urban              Medium
# 4              Mid         Graduate    Semi-Urban                High
# ...            ...              ...           ...                 ...
# 4995          High               PG    Semi-Urban                High
# 4996           Mid               PG         Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
# 4998          High        Upto 10th         Urban                 Low
# 4999           Mid             12th         Urban                 Low
#
#      mental_health_issues admission_taken  dropout
# 0                      No              No        1
# 1                     Yes              No        0
# 2                     Yes              No        1
# 3                     Yes             Yes        0
# 4                      No             Yes        0
# ...                   ...             ...      ...
# 4995                  Yes             Yes        0
# 4996                  Yes             Yes        0
# 4997                  Yes             Yes        0
# 4998                   No             Yes        0
# 4999                  Yes              No        0
#
# [5000 rows x 15 columns]

# %% [markdown]
# #### You can see the change in the 1st row under the "JEE_MAIN_SCORE" column
# #### this can be done with multiple values as well (lets change the first three curricula to State)

# %%
jee.loc[0:3,"school_board"] = "State"
jee
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86        State
# 1              80.00               58.75                64.33        State
# 2              81.07               37.27                60.83        State
# 3              93.32               60.72                69.33        State
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0                70.09              1            FIITJEE                5.4
# 1                78.00              1            FIITJEE                5.5
# 2                64.36              1            FIITJEE                7.0
# 3                73.21              1            FIITJEE                2.1
# 4                89.02              1              Allen                6.3
# ...                ...            ...                ...                ...
# 4995             84.45              1            FIITJEE                4.7
# 4996             73.02              2              Local                4.7
# 4997             77.87              2                NaN                6.3
# 4998             62.25              1              Allen                4.0
# 4999             94.90              2            FIITJEE                2.1
#
#      family_income parent_education location_type peer_pressure_level  \
# 0              Low        Upto 10th         Urban                 Low
# 1              Mid        Upto 10th         Urban                 Low
# 2              Low               PG    Semi-Urban              Medium
# 3              Low             12th    Semi-Urban              Medium
# 4              Mid         Graduate    Semi-Urban                High
# ...            ...              ...           ...                 ...
# 4995          High               PG    Semi-Urban                High
# 4996           Mid               PG         Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
# 4998          High        Upto 10th         Urban                 Low
# 4999           Mid             12th         Urban                 Low
#
#      mental_health_issues admission_taken  dropout
# 0                      No              No        1
# 1                     Yes              No        0
# 2                     Yes              No        1
# 3                     Yes             Yes        0
# 4                      No             Yes        0
# ...                   ...             ...      ...
# 4995                  Yes             Yes        0
# 4996                  Yes             Yes        0
# 4997                  Yes             Yes        0
# 4998                   No             Yes        0
# 4999                  Yes              No        0
#
# [5000 rows x 15 columns]

# %% [markdown]
# ## .iat and .at

# %%
jee.at[0,"school_board"]
# Out:
# 'State'

# %%
jee.iat[0,3]
# Out:
# 'State'

# %% [markdown]
# #### here you can see that through '.at' and '.iat' (Integer at, only integers allowed), we were able to select the same thing. This can also be done using loc and iloc

# %%
jee.loc[0,"school_board"]
# Out:
# 'State'

# %%
jee.iloc[0,3]
# Out:
# 'State'

# %% [markdown]
# ## Accessing Data

# %%
jee["jee_advanced_score"]
# Out:
# 0       59.22
# 1       58.75
# 2       37.27
# 3       60.72
# 4       77.73
#         ...
# 4995    86.82
# 4996    34.03
# 4997    54.71
# 4998    73.93
# 4999    76.31
# Name: jee_advanced_score, Length: 5000, dtype: float64

# %%
jee.school_board
# Out:
# 0        CBSE
# 1       State
# 2        ICSE
# 3        ICSE
# 4        CBSE
#         ...
# 4995    State
# 4996     CBSE
# 4997     CBSE
# 4998     CBSE
# 4999    State
# Name: school_board, Length: 5000, dtype: object

# %%
jee.sort_values(["jee_main_score","jee_advanced_score"], ascending=False).loc[0:,["coaching_institute","school_board","mental_health_issues","jee_main_score","jee_advanced_score"]]
# Out:
#      coaching_institute school_board mental_health_issues  jee_main_score  \
# 0               FIITJEE         CBSE                   No           78.95
# 1113            FIITJEE        State                   No           78.94
# 4741              Allen        State                  Yes           78.94
# 4312            FIITJEE         ICSE                  Yes           78.93
# 4206              Local         CBSE                   No           78.92
# ...                 ...          ...                  ...             ...
# 4198              Allen         CBSE                  Yes           29.89
# 2024              Local         ICSE                   No           29.73
# 4725              Local         ICSE                   No           27.61
# 4779            FIITJEE         ICSE                  Yes           27.53
# 262               Allen        State                  Yes           26.62
#
#       jee_advanced_score
# 0                  59.22
# 1113               52.03
# 4741               47.36
# 4312               83.25
# 4206               82.84
# ...                  ...
# 4198               26.20
# 2024               84.20
# 4725               61.21
# 4779               71.90
# 262                70.36
#
# [3442 rows x 5 columns]

# %% [markdown]
# #### It first sorts according to jee_main_score, and if there are values that are the same, it sorts according to jee_advanced_score

# %%
jee[jee.isnull().any(axis=1)]
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 7              82.74               73.80                58.62         CBSE
# 9              79.60               63.74                77.82        State
# 10             65.51               91.57                79.06         CBSE
# 15             64.13               57.81                68.50         CBSE
# 17             76.40               98.67                73.50        State
# ...              ...                 ...                  ...          ...
# 4973           42.80               75.66                64.51         CBSE
# 4975           52.77               57.33                63.99         CBSE
# 4980           55.23               58.87                53.67        State
# 4994           62.80               85.11                64.35        State
# 4997          100.00               54.71                83.75         CBSE
#
#       class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 7                77.15              1                NaN                2.2
# 9                94.96              2                NaN                2.7
# 10               66.88              1                NaN                5.5
# 15               74.68              2                NaN                6.0
# 17               78.29              1                NaN                4.0
# ...                ...            ...                ...                ...
# 4973             78.95              2                NaN                4.8
# 4975             68.00              2                NaN                3.6
# 4980             88.74              1                NaN                4.7
# 4994             89.05              1                NaN                0.6
# 4997             77.87              2                NaN                6.3
#
#      family_income parent_education location_type peer_pressure_level  \
# 7             High             12th         Urban                 Low
# 9              Mid             12th         Rural                High
# 10             Mid         Graduate         Urban                 Low
# 15            High         Graduate    Semi-Urban                 Low
# 17            High               PG         Rural                High
# ...            ...              ...           ...                 ...
# 4973          High               PG         Urban              Medium
# 4975           Mid        Upto 10th         Urban                 Low
# 4980           Mid             12th    Semi-Urban                 Low
# 4994          High             12th    Semi-Urban                High
# 4997           Mid               PG    Semi-Urban              Medium
#
#      mental_health_issues admission_taken  dropout
# 7                      No             Yes        0
# 9                     Yes              No        0
# 10                     No             Yes        0
# 15                     No              No        0
# 17                    Yes             Yes        0
# ...                   ...             ...      ...
# 4973                   No             Yes        0
# 4975                  Yes             Yes        0
# 4980                  Yes              No        0
# 4994                  Yes             Yes        1
# 4997                  Yes             Yes        0
#
# [1209 rows x 15 columns]

# %% [markdown]
# ### This prints the rows that have NaN anywhere in the row
